# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os, cv2, json, itertools, tempfile
from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dropout, BatchNormalization, GlobalAveragePooling2D, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from google.colab import drive
from tensorflow import keras
from keras.models import load_model
# %load_ext tensorboard

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
g_path = '/content/gdrive'
image_path = g_path + '/My Drive/Colab Notebooks' + '/archive'
image_dir_list = os.listdir(image_path)

print(image_dir_list)
# Out:
# ['readme.txt', 'label_map.json', 'test.csv', 'validation.csv', 'train.csv', 'images_train_test_val', 'images']

# %% [markdown]
# ### Analyse the data and classes

# %%
im_dataset_path = image_path + "/images"
json_file_path = image_path + "/label_map.json"

with open(json_file_path,"r") as j_file:
    class_name_cats = json.load(j_file)

len_classes = len(class_name_cats)
out_classes = list(class_name_cats.keys())
class_name_cats
# Out:
# {'agricultural': 0,
#  'airplane': 1,
#  'baseballdiamond': 2,
#  'beach': 3,
#  'buildings': 4,
#  'chaparral': 5,
#  'denseresidential': 6,
#  'forest': 7,
#  'freeway': 8,
#  'golfcourse': 9,
#  'intersection': 10,
#  'mediumresidential': 11,
#  'mobilehomepark': 12,
#  'overpass': 13,
#  'parkinglot': 14,
#  'river': 15,
#  'runway': 16,
#  'sparseresidential': 17,
#  'storagetanks': 18,
#  'tenniscourt': 19,
#  'harbor': 20}

# %% [markdown]
# ### Load image dataset

# %%
def load_image_data(csv_file):
    images_arr = []
    labels_arr = []
    img_csv = pd.read_csv(csv_file,index_col="Unnamed: 0")

    for i in tqdm(range(img_csv.shape[0])):
        image_name = img_csv.loc[i,'Filename']
        image = load_img(os.path.join(im_dataset_path,image_name),target_size=(224,224))

        image = img_to_array(image)
        image = preprocess_input(image)
        label = img_csv.loc[i,'Label']
        
        images_arr.append(image)
        labels_arr.append(label)
    
    images_arr = np.array(images_arr)
    labels_arr = np.array(labels_arr)
    return images_arr, labels_arr

# %%
train_im_path = image_path + "/train.csv"
val_im_path = image_path + "/validation.csv"
test_im_path = image_path + "/test.csv"

train_imgs, train_classes = load_image_data(train_im_path)
val_imgs, val_classes = load_image_data(val_im_path)
test_imgs, test_classes = load_image_data(test_im_path)

train_imgs.shape, train_classes.shape, val_imgs.shape, val_classes.shape, test_imgs.shape, test_classes.shape
# Out:
# 100%|██████████| 7350/7350 [1:34:37<00:00,  1.29it/s]
# 100%|██████████| 2100/2100 [26:14<00:00,  1.33it/s]
# 100%|██████████| 1050/1050 [13:09<00:00,  1.33it/s]
# ((7350, 224, 224, 3),
#  (7350,),
#  (2100, 224, 224, 3),
#  (2100,),
#  (1050, 224, 224, 3),
#  (1050,))

# %%
train_classes = to_categorical(train_classes)
val_classes = to_categorical(val_classes)
test_classes = to_categorical(test_classes)

print(train_classes.shape)
print(val_classes.shape)
print(test_classes.shape)
# Out:
# (7350, 21)
# (2100, 21)
# (1050, 21)

# %%
# # train_dir = image_path + "/images_train_test_val/train"
# # val_dir = image_path + "/images_train_test_val/validation"

# batchSize = 32

# Img_gen = ImageDataGenerator(horizontal_flip=True)

# train_img_gen = Img_gen.flow(train_imgs, train_classes,
#                                         #  target_size=(224,224),
#                                          class_mode='categorical',
#                                          batch_size=batchSize,
#                                          color_mode='rgb',
#                                          shuffle=True)
#                                         #  seed=42)

# # val_img_gen = Img_gen.flow_from_directory(val_imgs, val_classes,
# # val_img_gen = Img_gen.flow(val_imgs, val_classes,                                      
# #                                         # target_size=(224,224),
# #                                         # class_mode='categorical',
# #                                         batch_size=batchSize,
# #                                         # color_mode='rgb',
# #                                         shuffle=True,
# #                                         seed=42)

# %% [markdown]
# ### Resnet50V2 Model

# %%
Resnet50V2_model = tf.keras.applications.ResNet50V2(weights='imagenet',input_shape=(224, 224, 3),include_top=False)

# Add pooling layer
inputs = Resnet50V2_model.output
inputs = GlobalAveragePooling2D()(inputs)

# Add dropout layer
inputs = Dropout(0.5)(inputs)

# Add fully-connected dense layer
inputs = Dense(1024, activation='relu')(inputs)

# Add Softmax Layer for outputs classes
preds = Dense(21, activation='softmax')(inputs)
model = Model(inputs=Resnet50V2_model.input, outputs=preds)

# %% [markdown]
# ### Compile Model

# %%
# Compile Model
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Plot Model network

# %%
# plot_model(model,to_file='MobileNet_transfer_model.png',show_shapes=True,show_layer_names=True)
# SVG(model_to_dot(model).create(prog='dot',format='svg'))

# %% [markdown]
# ### Train Model

# %%
epochs = 40
batchSize = 10

history = model.fit(train_imgs, train_classes,
                      steps_per_epoch=len(train_imgs)//batchSize,
                      epochs=epochs,
                      verbose=1,
                      validation_data=(val_imgs, val_classes),
                      validation_steps=len(val_imgs)//batchSize)
                      # callbacks=[MobileNet_checkpoint, MobileNet_logs])
# Out:
# Epoch 1/40
# 735/735 [==============================] - 40s 48ms/step - loss: 2.3322 - accuracy: 0.2852 - val_loss: 2.4313 - val_accuracy: 0.3910
# Epoch 2/40
# 735/735 [==============================] - 34s 46ms/step - loss: 1.5814 - accuracy: 0.4782 - val_loss: 1.5900 - val_accuracy: 0.5514
# Epoch 3/40
# 735/735 [==============================] - 34s 46ms/step - loss: 1.2089 - accuracy: 0.6079 - val_loss: 1.2655 - val_accuracy: 0.6352
# Epoch 4/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.9366 - accuracy: 0.7008 - val_loss: 0.9162 - val_accuracy: 0.7214
# Epoch 5/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.7349 - accuracy: 0.7622 - val_loss: 0.8795 - val_accuracy: 0.7376
# Epoch 6/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.6119 - accuracy: 0.8035 - val_loss: 0.6260 - val_accuracy: 0.8010
# Epoch 7/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.4993 - accuracy: 0.8405 - val_loss: 0.6224 - val_accuracy: 0.8257
# Epoch 8/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.4325 - accuracy: 0.8592 - val_loss: 0.6736 - val_accuracy: 0.8086
# Epoch 9/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.3515 - accuracy: 0.8837 - val_loss: 0.5426 - val_accuracy: 0.8376
# Epoch 10/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.3327 - accuracy: 0.8951 - val_loss: 0.7161 - val_accuracy: 0.8229
# Epoch 11/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.2816 - accuracy: 0.9101 - val_loss: 0.5171 - val_accuracy: 0.8400
# Epoch 12/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.2425 - accuracy: 0.9190 - val_loss: 0.4719 - val_accuracy: 0.8652
# Epoch 13/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.2175 - accuracy: 0.9321 - val_loss: 0.4555 - val_accuracy: 0.8743
# Epoch 14/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.2180 - accuracy: 0.9310 - val_loss: 0.3830 - val_accuracy: 0.8967
# Epoch 15/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1916 - accuracy: 0.9404 - val_loss: 0.5359 - val_accuracy: 0.8595
# Epoch 16/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1659 - accuracy: 0.9503 - val_loss: 0.3626 - val_accuracy: 0.8895
# Epoch 17/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1438 - accuracy: 0.9544 - val_loss: 0.4747 - val_accuracy: 0.8790
# Epoch 18/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1605 - accuracy: 0.9525 - val_loss: 0.4066 - val_accuracy: 0.8924
# Epoch 19/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1218 - accuracy: 0.9638 - val_loss: 0.7784 - val_accuracy: 0.8381
# Epoch 20/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1305 - accuracy: 0.9595 - val_loss: 0.8773 - val_accuracy: 0.8314
# Epoch 21/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1388 - accuracy: 0.9547 - val_loss: 0.5370 - val_accuracy: 0.8667
# Epoch 22/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1297 - accuracy: 0.9592 - val_loss: 0.7534 - val_accuracy: 0.8524
# Epoch 23/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1020 - accuracy: 0.9701 - val_loss: 0.3636 - val_accuracy: 0.9162
# Epoch 24/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1158 - accuracy: 0.9652 - val_loss: 0.5153 - val_accuracy: 0.8910
# Epoch 25/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1043 - accuracy: 0.9717 - val_loss: 0.5601 - val_accuracy: 0.8776
# Epoch 26/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1040 - accuracy: 0.9691 - val_loss: 0.4147 - val_accuracy: 0.9029
# Epoch 27/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1033 - accuracy: 0.9694 - val_loss: 0.4596 - val_accuracy: 0.9024
# Epoch 28/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0845 - accuracy: 0.9746 - val_loss: 0.5120 - val_accuracy: 0.9024
# Epoch 29/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0806 - accuracy: 0.9754 - val_loss: 0.4346 - val_accuracy: 0.9033
# Epoch 30/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0898 - accuracy: 0.9728 - val_loss: 0.6412 - val_accuracy: 0.8610
# Epoch 31/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0983 - accuracy: 0.9729 - val_loss: 0.3961 - val_accuracy: 0.9062
# Epoch 32/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0937 - accuracy: 0.9739 - val_loss: 0.6136 - val_accuracy: 0.8824
# Epoch 33/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0784 - accuracy: 0.9777 - val_loss: 0.4338 - val_accuracy: 0.9110
# Epoch 34/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0756 - accuracy: 0.9777 - val_loss: 1.0096 - val_accuracy: 0.8214
# Epoch 35/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0822 - accuracy: 0.9761 - val_loss: 0.5098 - val_accuracy: 0.8895
# Epoch 36/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0643 - accuracy: 0.9807 - val_loss: 0.6117 - val_accuracy: 0.8781
# Epoch 37/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.1001 - accuracy: 0.9703 - val_loss: 0.3724 - val_accuracy: 0.9090
# Epoch 38/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0702 - accuracy: 0.9790 - val_loss: 0.5003 - val_accuracy: 0.8914
# Epoch 39/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0796 - accuracy: 0.9784 - val_loss: 0.5784 - val_accuracy: 0.8933
# Epoch 40/40
# 735/735 [==============================] - 34s 46ms/step - loss: 0.0663 - accuracy: 0.9804 - val_loss: 0.4144 - val_accuracy: 0.9124

# %% [markdown]
# ### Show history of traning and validation Accuracy

# %%
def summarize(history):
    
    plt.style.use("ggplot")
    fig, axes = plt.subplots(1,2,figsize=(16,6))

    #Plot loss     
    axes[0].set_title('Cross Entropy Loss')
    axes[0].plot(history.history['loss'], color='blue', label="Train")
    axes[0].plot(history.history['val_loss'], color='orange', label="Validation")
    axes[0].legend(loc='upper right')

    #Plot Accuracy 
    axes[1].set_title('Classification Accuracy')
    axes[1].plot(history.history['accuracy'], color='blue', label="Train")
    axes[1].plot(history.history['val_accuracy'], color='orange', label="Validation")
    axes[1].legend(loc='lower right')
    
    plt.show();
    pass

# %%
summarize(history)

# %% [markdown]
# ### Validation and Confusion Matrix

# %%
def show_conf_matrix(conf_mtx, classes, cmap=plt.cm.Blues):
    
    conf_mtx = conf_mtx.astype('float')/conf_mtx.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(20,20))
    plt.imshow(conf_mtx, interpolation='nearest', cmap=cmap)
    plt.title("Confusion Matrix")
    plt.colorbar()
    
    marks = np.arange(len(classes))
    plt.xticks(marks, classes,rotation=90)
    plt.yticks(marks, classes)
    
    fmrt = '.2f'
    limit = conf_mtx.max()/2.0   
    for i,j in itertools.product(range(conf_mtx.shape[0]), range(conf_mtx.shape[1])):
        plt.text(j,i, format(conf_mtx[i,j], fmrt),
                horizontalalignment = "center",
                color = "white" if conf_mtx[i,j] > limit else "black")
    
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.grid(None);

# %%
val_predict = model.predict(val_imgs)
val_predict = np.argmax(val_predict, axis=1)
val_predict.shape
# Out:
# (2100,)

# %%
val_actual = np.argmax(val_classes, axis=1)

conf_matrix = confusion_matrix(val_actual, val_predict)
np.set_printoptions(precision=2)

plt.figure() 
show_conf_matrix(conf_matrix, classes=out_classes)
plt.grid(None)
plt.show()

# %% [markdown]
# ### Make Predictions

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
#Formula
# accuracy: (tp + tn) / (p + n)
Resnet50V2_Accuracy = accuracy_score(val_actual, val_predict)
print('Resnet50V2 - Validation Accuracy: %f' % Resnet50V2_Accuracy)

#Formula
# precision tp / (tp + fp)
Resnet50V2_precision = precision_score(val_actual, val_predict, average="weighted")
print('Resnet50V2 - Precision : %f' % Resnet50V2_precision)

#Formula
# recall: tp / (tp + fn)
Resnet50V2_recall = recall_score(val_actual, val_predict, average="weighted")
print('Resnet50V2 - Recall : %f' % Resnet50V2_recall)

#Formula
# f1: 2 tp / (2 tp + fp + fn)
Resnet50V2_f1_sc = f1_score(val_actual, val_predict, average="weighted")
print('Resnet50V2 - F1 score : %f' % Resnet50V2_f1_sc)
# Out:
# Resnet50V2 - Validation Accuracy: 0.912381
# Resnet50V2 - Precision : 0.920715
# Resnet50V2 - Recall : 0.912381
# Resnet50V2 - F1 score : 0.913494

# %%
_, model_base_acc = model.evaluate(
   test_imgs, test_classes, verbose=0)

print('Test accuracy for base:', model_base_acc)
# Out:
# Test accuracy for base: 0.9047619104385376

# %% [markdown]
# ### Save the model

# %%
# model.save("/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/Resnet50V2/Resnet50V2_New_04.h5")

# %%
Resnet50V2_base_fin = load_model('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/Resnet50V2/Resnet50V2_New_04.h5')

# %% [markdown]
# ### Calculate Inference time

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = Resnet50V2_base_fin.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
print("Inference time is: ", ir_time)
# Out:
# Predicted Class is: 1
# Inference time is:  0.8322773539985064

# %% [markdown]
# ## Model Pruning

# %%
# !pip install tensorflow_model_optimization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_model_optimization
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 2.0 MB/s
# Requirement already satisfied: numpy~=1.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (1.21.6)
# Requirement already satisfied: six~=1.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (1.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (0.1.7)
# Installing collected packages: tensorflow-model-optimization
# Successfully installed tensorflow-model-optimization-0.7.3

# %%
import tensorflow_model_optimization as tfmot
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
# Compute end step to finish pruning after 2 epochs.
batch_size = 10
epochs = 30

end_step = np.ceil(train_imgs.shape[0]//batch_size).astype(np.int32) * epochs

# Define model for pruning.
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=end_step)
}

model_for_pruning = prune_low_magnitude(Resnet50V2_base_fin, **pruning_params)
# `prune_low_magnitude` requires a recompile.
model_for_pruning.compile(optimizer='adam',
              # loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model_for_pruning.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  prune_low_magnitude_conv1_pad   (None, 230, 230, 3)  1          ['input_2[0][0]']
#  (PruneLowMagnitude)
#
#  prune_low_magnitude_conv1_conv  (None, 112, 112, 64  18882      ['prune_low_magnitude_conv1_pad[0
#   (PruneLowMagnitude)           )                                ][0]']
#
#  prune_low_magnitude_pool1_pad   (None, 114, 114, 64  1          ['prune_low_magnitude_conv1_conv[
#  (PruneLowMagnitude)            )                                0][0]']
#
#  prune_low_magnitude_pool1_pool  (None, 56, 56, 64)  1           ['prune_low_magnitude_pool1_pad[0
#   (PruneLowMagnitude)                                            ][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  257         ['prune_low_magnitude_pool1_pool[
#  k1_preact_bn (PruneLowMagnitud                                  0][0]']
#  e)
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  1           ['prune_low_magnitude_conv2_block
#  k1_preact_relu (PruneLowMagnit                                  1_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  8194        ['prune_low_magnitude_conv2_block
#  k1_1_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  257         ['prune_low_magnitude_conv2_block
#  k1_1_bn (PruneLowMagnitude)                                     1_1_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  1           ['prune_low_magnitude_conv2_block
#  k1_1_relu (PruneLowMagnitude)                                   1_1_bn[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 58, 58, 64)  1           ['prune_low_magnitude_conv2_block
#  k1_2_pad (PruneLowMagnitude)                                    1_1_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  73730       ['prune_low_magnitude_conv2_block
#  k1_2_conv (PruneLowMagnitude)                                   1_2_pad[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  257         ['prune_low_magnitude_conv2_block
#  k1_2_bn (PruneLowMagnitude)                                     1_2_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  1           ['prune_low_magnitude_conv2_block
#  k1_2_relu (PruneLowMagnitude)                                   1_2_bn[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  33026      ['prune_low_magnitude_conv2_block
#  k1_0_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  33026      ['prune_low_magnitude_conv2_block
#  k1_3_conv (PruneLowMagnitude)                                   1_2_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  1          ['prune_low_magnitude_conv2_block
#  k1_out (PruneLowMagnitude)                                      1_0_conv[0][0]',
#                                                                   'prune_low_magnitude_conv2_block
#                                                                  1_3_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  1025       ['prune_low_magnitude_conv2_block
#  k2_preact_bn (PruneLowMagnitud                                  1_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  1          ['prune_low_magnitude_conv2_block
#  k2_preact_relu (PruneLowMagnit                                  2_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  32770       ['prune_low_magnitude_conv2_block
#  k2_1_conv (PruneLowMagnitude)                                   2_preact_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  257         ['prune_low_magnitude_conv2_block
#  k2_1_bn (PruneLowMagnitude)                                     2_1_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  1           ['prune_low_magnitude_conv2_block
#  k2_1_relu (PruneLowMagnitude)                                   2_1_bn[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 58, 58, 64)  1           ['prune_low_magnitude_conv2_block
#  k2_2_pad (PruneLowMagnitude)                                    2_1_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  73730       ['prune_low_magnitude_conv2_block
#  k2_2_conv (PruneLowMagnitude)                                   2_2_pad[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  257         ['prune_low_magnitude_conv2_block
#  k2_2_bn (PruneLowMagnitude)                                     2_2_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  1           ['prune_low_magnitude_conv2_block
#  k2_2_relu (PruneLowMagnitude)                                   2_2_bn[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  33026      ['prune_low_magnitude_conv2_block
#  k2_3_conv (PruneLowMagnitude)                                   2_2_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  1          ['prune_low_magnitude_conv2_block
#  k2_out (PruneLowMagnitude)                                      1_out[0][0]',
#                                                                   'prune_low_magnitude_conv2_block
#                                                                  2_3_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  1025       ['prune_low_magnitude_conv2_block
#  k3_preact_bn (PruneLowMagnitud                                  2_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 256)  1          ['prune_low_magnitude_conv2_block
#  k3_preact_relu (PruneLowMagnit                                  3_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  32770       ['prune_low_magnitude_conv2_block
#  k3_1_conv (PruneLowMagnitude)                                   3_preact_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  257         ['prune_low_magnitude_conv2_block
#  k3_1_bn (PruneLowMagnitude)                                     3_1_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 56, 56, 64)  1           ['prune_low_magnitude_conv2_block
#  k3_1_relu (PruneLowMagnitude)                                   3_1_bn[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 58, 58, 64)  1           ['prune_low_magnitude_conv2_block
#  k3_2_pad (PruneLowMagnitude)                                    3_1_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 28, 28, 64)  73730       ['prune_low_magnitude_conv2_block
#  k3_2_conv (PruneLowMagnitude)                                   3_2_pad[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 28, 28, 64)  257         ['prune_low_magnitude_conv2_block
#  k3_2_bn (PruneLowMagnitude)                                     3_2_conv[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 28, 28, 64)  1           ['prune_low_magnitude_conv2_block
#  k3_2_relu (PruneLowMagnitude)                                   3_2_bn[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 28, 28, 256)  1          ['prune_low_magnitude_conv2_block
#  g2d_3 (PruneLowMagnitude)                                       2_out[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 28, 28, 256)  33026      ['prune_low_magnitude_conv2_block
#  k3_3_conv (PruneLowMagnitude)                                   3_2_relu[0][0]']
#
#  prune_low_magnitude_conv2_bloc  (None, 28, 28, 256)  1          ['prune_low_magnitude_max_pooling
#  k3_out (PruneLowMagnitude)                                      2d_3[0][0]',
#                                                                   'prune_low_magnitude_conv2_block
#                                                                  3_3_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 256)  1025       ['prune_low_magnitude_conv2_block
#  k1_preact_bn (PruneLowMagnitud                                  3_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 256)  1          ['prune_low_magnitude_conv3_block
#  k1_preact_relu (PruneLowMagnit                                  1_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  65538      ['prune_low_magnitude_conv3_block
#  k1_1_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k1_1_bn (PruneLowMagnitude)                                     1_1_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k1_1_relu (PruneLowMagnitude)                                   1_1_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 30, 30, 128)  1          ['prune_low_magnitude_conv3_block
#  k1_2_pad (PruneLowMagnitude)                                    1_1_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  294914     ['prune_low_magnitude_conv3_block
#  k1_2_conv (PruneLowMagnitude)                                   1_2_pad[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k1_2_bn (PruneLowMagnitude)                                     1_2_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k1_2_relu (PruneLowMagnitude)                                   1_2_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  262658     ['prune_low_magnitude_conv3_block
#  k1_0_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  131586     ['prune_low_magnitude_conv3_block
#  k1_3_conv (PruneLowMagnitude)                                   1_2_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  1          ['prune_low_magnitude_conv3_block
#  k1_out (PruneLowMagnitude)                                      1_0_conv[0][0]',
#                                                                   'prune_low_magnitude_conv3_block
#                                                                  1_3_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  2049       ['prune_low_magnitude_conv3_block
#  k2_preact_bn (PruneLowMagnitud                                  1_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  1          ['prune_low_magnitude_conv3_block
#  k2_preact_relu (PruneLowMagnit                                  2_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  131074     ['prune_low_magnitude_conv3_block
#  k2_1_conv (PruneLowMagnitude)                                   2_preact_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k2_1_bn (PruneLowMagnitude)                                     2_1_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k2_1_relu (PruneLowMagnitude)                                   2_1_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 30, 30, 128)  1          ['prune_low_magnitude_conv3_block
#  k2_2_pad (PruneLowMagnitude)                                    2_1_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  294914     ['prune_low_magnitude_conv3_block
#  k2_2_conv (PruneLowMagnitude)                                   2_2_pad[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k2_2_bn (PruneLowMagnitude)                                     2_2_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k2_2_relu (PruneLowMagnitude)                                   2_2_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  131586     ['prune_low_magnitude_conv3_block
#  k2_3_conv (PruneLowMagnitude)                                   2_2_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  1          ['prune_low_magnitude_conv3_block
#  k2_out (PruneLowMagnitude)                                      1_out[0][0]',
#                                                                   'prune_low_magnitude_conv3_block
#                                                                  2_3_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  2049       ['prune_low_magnitude_conv3_block
#  k3_preact_bn (PruneLowMagnitud                                  2_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  1          ['prune_low_magnitude_conv3_block
#  k3_preact_relu (PruneLowMagnit                                  3_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  131074     ['prune_low_magnitude_conv3_block
#  k3_1_conv (PruneLowMagnitude)                                   3_preact_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k3_1_bn (PruneLowMagnitude)                                     3_1_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k3_1_relu (PruneLowMagnitude)                                   3_1_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 30, 30, 128)  1          ['prune_low_magnitude_conv3_block
#  k3_2_pad (PruneLowMagnitude)                                    3_1_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  294914     ['prune_low_magnitude_conv3_block
#  k3_2_conv (PruneLowMagnitude)                                   3_2_pad[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k3_2_bn (PruneLowMagnitude)                                     3_2_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k3_2_relu (PruneLowMagnitude)                                   3_2_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  131586     ['prune_low_magnitude_conv3_block
#  k3_3_conv (PruneLowMagnitude)                                   3_2_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  1          ['prune_low_magnitude_conv3_block
#  k3_out (PruneLowMagnitude)                                      2_out[0][0]',
#                                                                   'prune_low_magnitude_conv3_block
#                                                                  3_3_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  2049       ['prune_low_magnitude_conv3_block
#  k4_preact_bn (PruneLowMagnitud                                  3_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 512)  1          ['prune_low_magnitude_conv3_block
#  k4_preact_relu (PruneLowMagnit                                  4_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  131074     ['prune_low_magnitude_conv3_block
#  k4_1_conv (PruneLowMagnitude)                                   4_preact_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  513        ['prune_low_magnitude_conv3_block
#  k4_1_bn (PruneLowMagnitude)                                     4_1_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 28, 28, 128)  1          ['prune_low_magnitude_conv3_block
#  k4_1_relu (PruneLowMagnitude)                                   4_1_bn[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 30, 30, 128)  1          ['prune_low_magnitude_conv3_block
#  k4_2_pad (PruneLowMagnitude)                                    4_1_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 14, 14, 128)  294914     ['prune_low_magnitude_conv3_block
#  k4_2_conv (PruneLowMagnitude)                                   4_2_pad[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 14, 14, 128)  513        ['prune_low_magnitude_conv3_block
#  k4_2_bn (PruneLowMagnitude)                                     4_2_conv[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 14, 14, 128)  1          ['prune_low_magnitude_conv3_block
#  k4_2_relu (PruneLowMagnitude)                                   4_2_bn[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 14, 14, 512)  1          ['prune_low_magnitude_conv3_block
#  g2d_4 (PruneLowMagnitude)                                       3_out[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 14, 14, 512)  131586     ['prune_low_magnitude_conv3_block
#  k4_3_conv (PruneLowMagnitude)                                   4_2_relu[0][0]']
#
#  prune_low_magnitude_conv3_bloc  (None, 14, 14, 512)  1          ['prune_low_magnitude_max_pooling
#  k4_out (PruneLowMagnitude)                                      2d_4[0][0]',
#                                                                   'prune_low_magnitude_conv3_block
#                                                                  4_3_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 512)  2049       ['prune_low_magnitude_conv3_block
#  k1_preact_bn (PruneLowMagnitud                                  4_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 512)  1          ['prune_low_magnitude_conv4_block
#  k1_preact_relu (PruneLowMagnit                                  1_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  262146     ['prune_low_magnitude_conv4_block
#  k1_1_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k1_1_bn (PruneLowMagnitude)                                     1_1_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k1_1_relu (PruneLowMagnitude)                                   1_1_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 16, 16, 256)  1          ['prune_low_magnitude_conv4_block
#  k1_2_pad (PruneLowMagnitude)                                    1_1_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1179650    ['prune_low_magnitude_conv4_block
#  k1_2_conv (PruneLowMagnitude)                                   1_2_pad[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k1_2_bn (PruneLowMagnitude)                                     1_2_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k1_2_relu (PruneLowMagnitude)                                   1_2_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1049602    ['prune_low_magnitude_conv4_block
#  k1_0_conv (PruneLowMagnitude)  )                                1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  525314     ['prune_low_magnitude_conv4_block
#  k1_3_conv (PruneLowMagnitude)  )                                1_2_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k1_out (PruneLowMagnitude)     )                                1_0_conv[0][0]',
#                                                                   'prune_low_magnitude_conv4_block
#                                                                  1_3_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  4097       ['prune_low_magnitude_conv4_block
#  k2_preact_bn (PruneLowMagnitud  )                               1_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k2_preact_relu (PruneLowMagnit  )                               2_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  524290     ['prune_low_magnitude_conv4_block
#  k2_1_conv (PruneLowMagnitude)                                   2_preact_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k2_1_bn (PruneLowMagnitude)                                     2_1_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k2_1_relu (PruneLowMagnitude)                                   2_1_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 16, 16, 256)  1          ['prune_low_magnitude_conv4_block
#  k2_2_pad (PruneLowMagnitude)                                    2_1_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1179650    ['prune_low_magnitude_conv4_block
#  k2_2_conv (PruneLowMagnitude)                                   2_2_pad[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k2_2_bn (PruneLowMagnitude)                                     2_2_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k2_2_relu (PruneLowMagnitude)                                   2_2_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  525314     ['prune_low_magnitude_conv4_block
#  k2_3_conv (PruneLowMagnitude)  )                                2_2_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k2_out (PruneLowMagnitude)     )                                1_out[0][0]',
#                                                                   'prune_low_magnitude_conv4_block
#                                                                  2_3_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  4097       ['prune_low_magnitude_conv4_block
#  k3_preact_bn (PruneLowMagnitud  )                               2_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k3_preact_relu (PruneLowMagnit  )                               3_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  524290     ['prune_low_magnitude_conv4_block
#  k3_1_conv (PruneLowMagnitude)                                   3_preact_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k3_1_bn (PruneLowMagnitude)                                     3_1_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k3_1_relu (PruneLowMagnitude)                                   3_1_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 16, 16, 256)  1          ['prune_low_magnitude_conv4_block
#  k3_2_pad (PruneLowMagnitude)                                    3_1_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1179650    ['prune_low_magnitude_conv4_block
#  k3_2_conv (PruneLowMagnitude)                                   3_2_pad[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k3_2_bn (PruneLowMagnitude)                                     3_2_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k3_2_relu (PruneLowMagnitude)                                   3_2_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  525314     ['prune_low_magnitude_conv4_block
#  k3_3_conv (PruneLowMagnitude)  )                                3_2_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k3_out (PruneLowMagnitude)     )                                2_out[0][0]',
#                                                                   'prune_low_magnitude_conv4_block
#                                                                  3_3_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  4097       ['prune_low_magnitude_conv4_block
#  k4_preact_bn (PruneLowMagnitud  )                               3_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k4_preact_relu (PruneLowMagnit  )                               4_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  524290     ['prune_low_magnitude_conv4_block
#  k4_1_conv (PruneLowMagnitude)                                   4_preact_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k4_1_bn (PruneLowMagnitude)                                     4_1_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k4_1_relu (PruneLowMagnitude)                                   4_1_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 16, 16, 256)  1          ['prune_low_magnitude_conv4_block
#  k4_2_pad (PruneLowMagnitude)                                    4_1_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1179650    ['prune_low_magnitude_conv4_block
#  k4_2_conv (PruneLowMagnitude)                                   4_2_pad[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k4_2_bn (PruneLowMagnitude)                                     4_2_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k4_2_relu (PruneLowMagnitude)                                   4_2_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  525314     ['prune_low_magnitude_conv4_block
#  k4_3_conv (PruneLowMagnitude)  )                                4_2_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k4_out (PruneLowMagnitude)     )                                3_out[0][0]',
#                                                                   'prune_low_magnitude_conv4_block
#                                                                  4_3_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  4097       ['prune_low_magnitude_conv4_block
#  k5_preact_bn (PruneLowMagnitud  )                               4_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k5_preact_relu (PruneLowMagnit  )                               5_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  524290     ['prune_low_magnitude_conv4_block
#  k5_1_conv (PruneLowMagnitude)                                   5_preact_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k5_1_bn (PruneLowMagnitude)                                     5_1_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k5_1_relu (PruneLowMagnitude)                                   5_1_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 16, 16, 256)  1          ['prune_low_magnitude_conv4_block
#  k5_2_pad (PruneLowMagnitude)                                    5_1_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1179650    ['prune_low_magnitude_conv4_block
#  k5_2_conv (PruneLowMagnitude)                                   5_2_pad[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1025       ['prune_low_magnitude_conv4_block
#  k5_2_bn (PruneLowMagnitude)                                     5_2_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 256)  1          ['prune_low_magnitude_conv4_block
#  k5_2_relu (PruneLowMagnitude)                                   5_2_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  525314     ['prune_low_magnitude_conv4_block
#  k5_3_conv (PruneLowMagnitude)  )                                5_2_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k5_out (PruneLowMagnitude)     )                                4_out[0][0]',
#                                                                   'prune_low_magnitude_conv4_block
#                                                                  5_3_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  4097       ['prune_low_magnitude_conv4_block
#  k6_preact_bn (PruneLowMagnitud  )                               5_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv4_bloc  (None, 14, 14, 1024  1          ['prune_low_magnitude_conv4_block
#  k6_preact_relu (PruneLowMagnit  )                               6_preact_bn[0][0]']
#  ude)
# ...
#  k6_1_relu (PruneLowMagnitude)                                   6_1_bn[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 16, 16, 256)  1          ['prune_low_magnitude_conv4_block
#  k6_2_pad (PruneLowMagnitude)                                    6_1_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 7, 7, 256)   1179650     ['prune_low_magnitude_conv4_block
#  k6_2_conv (PruneLowMagnitude)                                   6_2_pad[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 7, 7, 256)   1025        ['prune_low_magnitude_conv4_block
#  k6_2_bn (PruneLowMagnitude)                                     6_2_conv[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 7, 7, 256)   1           ['prune_low_magnitude_conv4_block
#  k6_2_relu (PruneLowMagnitude)                                   6_2_bn[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 7, 7, 1024)  1           ['prune_low_magnitude_conv4_block
#  g2d_5 (PruneLowMagnitude)                                       5_out[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 7, 7, 1024)  525314      ['prune_low_magnitude_conv4_block
#  k6_3_conv (PruneLowMagnitude)                                   6_2_relu[0][0]']
#
#  prune_low_magnitude_conv4_bloc  (None, 7, 7, 1024)  1           ['prune_low_magnitude_max_pooling
#  k6_out (PruneLowMagnitude)                                      2d_5[0][0]',
#                                                                   'prune_low_magnitude_conv4_block
#                                                                  6_3_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 1024)  4097        ['prune_low_magnitude_conv4_block
#  k1_preact_bn (PruneLowMagnitud                                  6_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 1024)  1           ['prune_low_magnitude_conv5_block
#  k1_preact_relu (PruneLowMagnit                                  1_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1048578     ['prune_low_magnitude_conv5_block
#  k1_1_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2049        ['prune_low_magnitude_conv5_block
#  k1_1_bn (PruneLowMagnitude)                                     1_1_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1           ['prune_low_magnitude_conv5_block
#  k1_1_relu (PruneLowMagnitude)                                   1_1_bn[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 9, 9, 512)   1           ['prune_low_magnitude_conv5_block
#  k1_2_pad (PruneLowMagnitude)                                    1_1_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   4718594     ['prune_low_magnitude_conv5_block
#  k1_2_conv (PruneLowMagnitude)                                   1_2_pad[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2049        ['prune_low_magnitude_conv5_block
#  k1_2_bn (PruneLowMagnitude)                                     1_2_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1           ['prune_low_magnitude_conv5_block
#  k1_2_relu (PruneLowMagnitude)                                   1_2_bn[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  4196354     ['prune_low_magnitude_conv5_block
#  k1_0_conv (PruneLowMagnitude)                                   1_preact_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  2099202     ['prune_low_magnitude_conv5_block
#  k1_3_conv (PruneLowMagnitude)                                   1_2_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  1           ['prune_low_magnitude_conv5_block
#  k1_out (PruneLowMagnitude)                                      1_0_conv[0][0]',
#                                                                   'prune_low_magnitude_conv5_block
#                                                                  1_3_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  8193        ['prune_low_magnitude_conv5_block
#  k2_preact_bn (PruneLowMagnitud                                  1_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  1           ['prune_low_magnitude_conv5_block
#  k2_preact_relu (PruneLowMagnit                                  2_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2097154     ['prune_low_magnitude_conv5_block
#  k2_1_conv (PruneLowMagnitude)                                   2_preact_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2049        ['prune_low_magnitude_conv5_block
#  k2_1_bn (PruneLowMagnitude)                                     2_1_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1           ['prune_low_magnitude_conv5_block
#  k2_1_relu (PruneLowMagnitude)                                   2_1_bn[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 9, 9, 512)   1           ['prune_low_magnitude_conv5_block
#  k2_2_pad (PruneLowMagnitude)                                    2_1_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   4718594     ['prune_low_magnitude_conv5_block
#  k2_2_conv (PruneLowMagnitude)                                   2_2_pad[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2049        ['prune_low_magnitude_conv5_block
#  k2_2_bn (PruneLowMagnitude)                                     2_2_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1           ['prune_low_magnitude_conv5_block
#  k2_2_relu (PruneLowMagnitude)                                   2_2_bn[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  2099202     ['prune_low_magnitude_conv5_block
#  k2_3_conv (PruneLowMagnitude)                                   2_2_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  1           ['prune_low_magnitude_conv5_block
#  k2_out (PruneLowMagnitude)                                      1_out[0][0]',
#                                                                   'prune_low_magnitude_conv5_block
#                                                                  2_3_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  8193        ['prune_low_magnitude_conv5_block
#  k3_preact_bn (PruneLowMagnitud                                  2_out[0][0]']
#  e)
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  1           ['prune_low_magnitude_conv5_block
#  k3_preact_relu (PruneLowMagnit                                  3_preact_bn[0][0]']
#  ude)
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2097154     ['prune_low_magnitude_conv5_block
#  k3_1_conv (PruneLowMagnitude)                                   3_preact_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2049        ['prune_low_magnitude_conv5_block
#  k3_1_bn (PruneLowMagnitude)                                     3_1_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1           ['prune_low_magnitude_conv5_block
#  k3_1_relu (PruneLowMagnitude)                                   3_1_bn[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 9, 9, 512)   1           ['prune_low_magnitude_conv5_block
#  k3_2_pad (PruneLowMagnitude)                                    3_1_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   4718594     ['prune_low_magnitude_conv5_block
#  k3_2_conv (PruneLowMagnitude)                                   3_2_pad[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   2049        ['prune_low_magnitude_conv5_block
#  k3_2_bn (PruneLowMagnitude)                                     3_2_conv[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 512)   1           ['prune_low_magnitude_conv5_block
#  k3_2_relu (PruneLowMagnitude)                                   3_2_bn[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  2099202     ['prune_low_magnitude_conv5_block
#  k3_3_conv (PruneLowMagnitude)                                   3_2_relu[0][0]']
#
#  prune_low_magnitude_conv5_bloc  (None, 7, 7, 2048)  1           ['prune_low_magnitude_conv5_block
#  k3_out (PruneLowMagnitude)                                      2_out[0][0]',
#                                                                   'prune_low_magnitude_conv5_block
#                                                                  3_3_conv[0][0]']
#
#  prune_low_magnitude_post_bn (P  (None, 7, 7, 2048)  8193        ['prune_low_magnitude_conv5_block
#  runeLowMagnitude)                                               3_out[0][0]']
#
#  prune_low_magnitude_post_relu   (None, 7, 7, 2048)  1           ['prune_low_magnitude_post_bn[0][
#  (PruneLowMagnitude)                                             0]']
#
#  prune_low_magnitude_global_ave  (None, 2048)        1           ['prune_low_magnitude_post_relu[0
#  rage_pooling2d_1 (PruneLowMagn                                  ][0]']
#  itude)
#
#  prune_low_magnitude_dropout_1   (None, 2048)        1           ['prune_low_magnitude_global_aver
#  (PruneLowMagnitude)                                             age_pooling2d_1[0][0]']
#
#  prune_low_magnitude_dense_2 (P  (None, 1024)        4195330     ['prune_low_magnitude_dropout_1[0
#  runeLowMagnitude)                                               ][0]']
#
#  prune_low_magnitude_dense_3 (P  (None, 21)          43031       ['prune_low_magnitude_dense_2[0][
#  runeLowMagnitude)                                               0]']
#
# ==================================================================================================
# Total params: 51,258,317
# Trainable params: 25,639,061
# Non-trainable params: 25,619,256
# __________________________________________________________________________________________________

# %%
logdir = tempfile.mkdtemp()

callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep(),
  tfmot.sparsity.keras.PruningSummaries(log_dir=logdir),
]
  
model_for_pruning.fit(train_imgs, train_classes,
                      steps_per_epoch=len(train_imgs)//10,
                      epochs=10, 
                      verbose=1,
                      validation_data=(val_imgs,val_classes),
                      validation_steps=len(val_imgs)//10)
                      # callbacks=callbacks)
# Out:
# Epoch 1/10
# 735/735 [==============================] - 94s 113ms/step - loss: 0.0398 - accuracy: 0.9865 - val_loss: 0.4427 - val_accuracy: 0.9114
# Epoch 2/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0391 - accuracy: 0.9879 - val_loss: 0.4876 - val_accuracy: 0.9152
# Epoch 3/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0476 - accuracy: 0.9871 - val_loss: 0.4839 - val_accuracy: 0.9157
# Epoch 4/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0460 - accuracy: 0.9864 - val_loss: 0.4373 - val_accuracy: 0.9186
# Epoch 5/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0342 - accuracy: 0.9905 - val_loss: 0.4623 - val_accuracy: 0.9176
# Epoch 6/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0347 - accuracy: 0.9910 - val_loss: 0.4282 - val_accuracy: 0.9071
# Epoch 7/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0306 - accuracy: 0.9906 - val_loss: 0.4798 - val_accuracy: 0.9262
# Epoch 8/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0482 - accuracy: 0.9882 - val_loss: 0.3487 - val_accuracy: 0.9305
# Epoch 9/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0301 - accuracy: 0.9894 - val_loss: 0.4390 - val_accuracy: 0.9267
# Epoch 10/10
# 735/735 [==============================] - 80s 109ms/step - loss: 0.0244 - accuracy: 0.9927 - val_loss: 0.4183 - val_accuracy: 0.9281

# %%
_, model_prun_acc = model_for_pruning.evaluate(
   test_imgs, test_classes, verbose=0)

# print('Test accuracy for base model:', model_base_acc) 
print('Test accuracy for Prunned model:', model_prun_acc)
# Out:
# Test accuracy for Prunned model: 0.915238082408905

# %%
model_for_pruning.save("/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/Resnet50V2/model_for_pruning_01.h5")

# %%
# model_for_pruning = load_model('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/Resnet50V2/model_for_pruning_01.h5')

# %%
val_pred_prun = model_for_pruning.predict(val_imgs)
val_pred_prun = np.argmax(val_pred_prun, axis=1)
val_pred_prun.shape
# Out:
# (2100,)

# %%
val_actual_prun = np.argmax(val_classes, axis=1)

cnf_mat = confusion_matrix(val_actual_prun, val_pred_prun)
np.set_printoptions(precision=2)

plt.figure()
show_conf_matrix(cnf_mat, classes=out_classes)
plt.grid(None)
plt.show();

# %% [markdown]
# ### Model Prediction Accuracy

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
#Formula
# accuracy: (tp + tn) / (p + n)
Resnet50V2_Accuracy_prun = accuracy_score(val_actual_prun, val_pred_prun)
print('Pruning Resnet50V2 - Validation Accuracy: %f' % Resnet50V2_Accuracy_prun)

#Formula
# precision tp / (tp + fp)
Resnet50V2_precision_prun = precision_score(val_actual_prun, val_pred_prun, average="weighted")
print('Pruning Resnet50V2 - Precision : %f' % Resnet50V2_precision_prun)

#Formula
# recall: tp / (tp + fn)
Resnet50V2_recall_prun = recall_score(val_actual_prun, val_pred_prun, average="weighted")
print('Pruning Resnet50V2 - Recall : %f' % Resnet50V2_recall_prun)

#Formula
# f1: 2 tp / (2 tp + fp + fn)
Resnet50V2_f1_sc_prun = f1_score(val_actual_prun, val_pred_prun, average="weighted")
print('Pruning Resnet50V2 - F1 score : %f' % Resnet50V2_f1_sc_prun)
# Out:
# Pruning Resnet50V2 - Validation Accuracy: 0.928095
# Pruning Resnet50V2 - Precision : 0.931357
# Pruning Resnet50V2 - Recall : 0.928095
# Pruning Resnet50V2 - F1 score : 0.928219

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = model_for_pruning.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
print("Inference time is: ", ir_time)
# Out:
# Predicted Class is: 1
# Inference time is:  0.052827006998995785

# %% [markdown]
# ### Grad-CAM Visual on Baseline Model

# %%
def grad_cam_heatmap(pred_img, model, lst_conv_layer, pred_index=None):
    #Created a model which maps the input image to activations of last conv layer and output predictions
    gradient_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(lst_conv_layer).output, model.output]
    )

    #Calculate gradient of top predicted class for input image for last conv layer activation
    with tf.GradientTape() as tape:
        lst_conv_layer_out, preds = gradient_model(pred_img)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channels = preds[:, pred_index]

    # Gradient of top predicted for output feature map of last conv layer
    grads = tape.gradient(class_channels, lst_conv_layer_out)

    # A vector of mean intensity of the gradient over feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Multipled each channel in the feature map array to check importance of channel 
    # with respect to top predicted class and sum of all channel to get heatmap of class activation
    lst_conv_layer_out = lst_conv_layer_out[0]
    heatmap = lst_conv_layer_out @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    #Normalize a heatmap between 0 and 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def grad_cam_display(org_img_path, heatmap, grad_cam_path="grad_cam.jpg", alpha=0.4):
    # Load an image
    img = tf.keras.preprocessing.image.load_img(org_img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to 0-255 range
    heatmap = np.uint8(255 * heatmap)

    # color heatmap using jet colourmap
    jet = cm.get_cmap("jet")

    # Use RGB colormap values
    jet_colors = jet(np.arange(256))[:, :3]
    jet_color_heatmap = jet_colors[heatmap]

    # Created an image with RGB colored heatmap
    jet_color_heatmap = tf.keras.preprocessing.image.array_to_img(jet_color_heatmap)
    jet_color_heatmap = jet_color_heatmap.resize((img.shape[1], img.shape[0]))
    jet_color_heatmap = tf.keras.preprocessing.image.img_to_array(jet_color_heatmap)

    # Superimpose a heatmap on actual image
    superimposed_img = jet_color_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)

    superimposed_img.save(grad_cam_path)

    # Display Grad CAM
    # display(Image(grad_cam_path))
    
    return grad_cam_path
    
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input
decode_predictions = tf.keras.applications.mobilenet_v2.decode_predictions

lst_conv_layer = "conv5_block3_out"
img_size = (224,224)

# Remove last layer's softmax
Resnet50V2_base_fin.layers[-1].activation = None

# %% [markdown]
# ### Visualise image

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 
import matplotlib.cm as cm

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/intersection.png')

# predict the class
start = time.perf_counter()
pre_class = Resnet50V2_base_fin.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
# print("Inference time is: ", ir_time)

img_path = '/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model'

# Calculate Grad-CAM class activation
gc_heatmap = grad_cam_heatmap(pred_img, Resnet50V2_base_fin, lst_conv_layer)
# print(heatmap)
g_cam_path = grad_cam_display('/content/gdrive/My Drive/Colab Notebooks/intersection.png', gc_heatmap)
img = plt.imread(g_cam_path)
img = plt.imshow(img)

print("\n\nGrad-CAM Visual")
print("Predicted Class is:", pre_class[0])
# Out:
# Predicted Class is: 18
#
#
# Grad-CAM Visual
# Predicted Class is: 18

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 
import matplotlib.cm as cm

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = Resnet50V2_base_fin.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
# print("Inference time is: ", ir_time)

img_path = '/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model'

# Calculate Grad-CAM class activation
gc_heatmap = grad_cam_heatmap(pred_img, Resnet50V2_base_fin, lst_conv_layer)
# print(heatmap)
g_cam_path = grad_cam_display('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif', gc_heatmap)
img = plt.imread(g_cam_path)
img = plt.imshow(img)

print("\n\nGrad-CAM Visual")
print("Predicted Class is:", pre_class[0])
# Out:
# Predicted Class is: 1
#
#
# Grad-CAM Visual
# Predicted Class is: 1
