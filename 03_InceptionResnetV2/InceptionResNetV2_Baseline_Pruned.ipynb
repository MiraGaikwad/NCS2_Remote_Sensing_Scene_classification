# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os, cv2, json, itertools, tempfile
from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dropout, BatchNormalization, GlobalAveragePooling2D, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from google.colab import drive
from tensorflow import keras
from keras.models import load_model
# %load_ext tensorboard

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
g_path = '/content/gdrive'
image_path = g_path + '/My Drive/Colab Notebooks' + '/archive'
image_dir_list = os.listdir(image_path)

print(image_dir_list)
# Out:
# ['readme.txt', 'label_map.json', 'test.csv', 'validation.csv', 'train.csv', 'images_train_test_val', 'images']

# %% [markdown]
# ### Analyse the data and classes

# %%
im_dataset_path = image_path + "/images"
json_file_path = image_path + "/label_map.json"

with open(json_file_path,"r") as j_file:
    class_name_cats = json.load(j_file)

len_classes = len(class_name_cats)
out_classes = list(class_name_cats.keys())
class_name_cats
# Out:
# {'agricultural': 0,
#  'airplane': 1,
#  'baseballdiamond': 2,
#  'beach': 3,
#  'buildings': 4,
#  'chaparral': 5,
#  'denseresidential': 6,
#  'forest': 7,
#  'freeway': 8,
#  'golfcourse': 9,
#  'harbor': 20,
#  'intersection': 10,
#  'mediumresidential': 11,
#  'mobilehomepark': 12,
#  'overpass': 13,
#  'parkinglot': 14,
#  'river': 15,
#  'runway': 16,
#  'sparseresidential': 17,
#  'storagetanks': 18,
#  'tenniscourt': 19}

# %% [markdown]
# ### Load image dataset

# %%
def load_image_data(csv_file):
    images_arr = []
    labels_arr = []
    img_csv = pd.read_csv(csv_file,index_col="Unnamed: 0")

    for i in tqdm(range(img_csv.shape[0])):
        image_name = img_csv.loc[i,'Filename']
        image = load_img(os.path.join(im_dataset_path,image_name),target_size=(224,224))

        image = img_to_array(image)
        image = preprocess_input(image)
        label = img_csv.loc[i,'Label']
        
        images_arr.append(image)
        labels_arr.append(label)
    
    images_arr = np.array(images_arr)
    labels_arr = np.array(labels_arr)
    return images_arr, labels_arr

# %%
train_im_path = image_path + "/train.csv"
val_im_path = image_path + "/validation.csv"
test_im_path = image_path + "/test.csv"

train_imgs, train_classes = load_image_data(train_im_path)
val_imgs, val_classes = load_image_data(val_im_path)
test_imgs, test_classes = load_image_data(test_im_path)

train_imgs.shape, train_classes.shape, val_imgs.shape, val_classes.shape, test_imgs.shape, test_classes.shape
# Out:
# 100%|██████████| 7350/7350 [40:48<00:00,  3.00it/s]
# 100%|██████████| 2100/2100 [11:13<00:00,  3.12it/s]
# 100%|██████████| 1050/1050 [05:35<00:00,  3.13it/s]
# ((7350, 224, 224, 3),
#  (7350,),
#  (2100, 224, 224, 3),
#  (2100,),
#  (1050, 224, 224, 3),
#  (1050,))

# %%
train_classes = to_categorical(train_classes)
val_classes = to_categorical(val_classes)
test_classes = to_categorical(test_classes)

print(train_classes.shape)
print(val_classes.shape)
print(test_classes.shape)
# Out:
# (7350, 21)
# (2100, 21)
# (1050, 21)

# %% [markdown]
# ### InceptionResnetV2 Model

# %%
InceptionResNetV2_model = tf.keras.applications.InceptionResNetV2(weights='imagenet',input_shape=(224, 224, 3),include_top=False)

InceptionResNetV2_model.trainable = False

# Add pooling layer
inputs = InceptionResNetV2_model.output
inputs = GlobalAveragePooling2D()(inputs)

# Add dropout layer
inputs = Dropout(0.5)(inputs)

# Add Batch normalization layer
inputs = BatchNormalization()(inputs)

# Add Softmax Layer for outputs classes
preds = Dense(21, activation='softmax')(inputs)
model = Model(inputs=InceptionResNetV2_model.input, outputs=preds)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 3s 0us/step
# 219070464/219055592 [==============================] - 3s 0us/step

# %% [markdown]
# ### Compile Model

# %%
# Compile Model
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Plot Model network

# %%
# plot_model(model,to_file='MobileNet_transfer_model.png',show_shapes=True,show_layer_names=True)
# SVG(model_to_dot(model).create(prog='dot',format='svg'))

# %% [markdown]
# ### Train Model

# %%
epochs = 40
batchSize = 10

history = model.fit(train_imgs, train_classes,
                      steps_per_epoch=len(train_imgs)//batchSize,
                      epochs=epochs,
                      verbose=1,
                      validation_data=(val_imgs, val_classes),
                      validation_steps=len(val_imgs)//batchSize)
                      # callbacks=[MobileNet_checkpoint, MobileNet_logs])
# Out:
# Epoch 1/40
# 735/735 [==============================] - 61s 56ms/step - loss: 1.2167 - accuracy: 0.6331 - val_loss: 0.3883 - val_accuracy: 0.8757
# Epoch 2/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.6497 - accuracy: 0.7898 - val_loss: 0.3043 - val_accuracy: 0.9067
# Epoch 3/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5770 - accuracy: 0.8148 - val_loss: 0.2649 - val_accuracy: 0.9110
# Epoch 4/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5429 - accuracy: 0.8284 - val_loss: 0.2677 - val_accuracy: 0.9148
# Epoch 5/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5242 - accuracy: 0.8340 - val_loss: 0.2449 - val_accuracy: 0.9162
# Epoch 6/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5077 - accuracy: 0.8410 - val_loss: 0.2549 - val_accuracy: 0.9195
# Epoch 7/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4982 - accuracy: 0.8463 - val_loss: 0.2379 - val_accuracy: 0.9238
# Epoch 8/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5366 - accuracy: 0.8336 - val_loss: 0.2494 - val_accuracy: 0.9233
# Epoch 9/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5152 - accuracy: 0.8393 - val_loss: 0.2421 - val_accuracy: 0.9176
# Epoch 10/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5177 - accuracy: 0.8403 - val_loss: 0.2405 - val_accuracy: 0.9267
# Epoch 11/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5238 - accuracy: 0.8418 - val_loss: 0.2359 - val_accuracy: 0.9252
# Epoch 12/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5091 - accuracy: 0.8444 - val_loss: 0.2457 - val_accuracy: 0.9262
# Epoch 13/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4999 - accuracy: 0.8490 - val_loss: 0.2762 - val_accuracy: 0.9129
# Epoch 14/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5149 - accuracy: 0.8433 - val_loss: 0.2384 - val_accuracy: 0.9233
# Epoch 15/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4994 - accuracy: 0.8494 - val_loss: 0.2356 - val_accuracy: 0.9271
# Epoch 16/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5228 - accuracy: 0.8426 - val_loss: 0.2311 - val_accuracy: 0.9348
# Epoch 17/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5159 - accuracy: 0.8459 - val_loss: 0.2321 - val_accuracy: 0.9305
# Epoch 18/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5057 - accuracy: 0.8439 - val_loss: 0.2333 - val_accuracy: 0.9257
# Epoch 19/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.5071 - accuracy: 0.8532 - val_loss: 0.2179 - val_accuracy: 0.9290
# Epoch 20/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4972 - accuracy: 0.8540 - val_loss: 0.2309 - val_accuracy: 0.9286
# Epoch 21/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4752 - accuracy: 0.8569 - val_loss: 0.2249 - val_accuracy: 0.9329
# Epoch 22/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4774 - accuracy: 0.8541 - val_loss: 0.2265 - val_accuracy: 0.9300
# Epoch 23/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4866 - accuracy: 0.8516 - val_loss: 0.2264 - val_accuracy: 0.9300
# Epoch 24/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4937 - accuracy: 0.8513 - val_loss: 0.2290 - val_accuracy: 0.9267
# Epoch 25/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4987 - accuracy: 0.8484 - val_loss: 0.2238 - val_accuracy: 0.9324
# Epoch 26/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4679 - accuracy: 0.8556 - val_loss: 0.2224 - val_accuracy: 0.9314
# Epoch 27/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4696 - accuracy: 0.8595 - val_loss: 0.2128 - val_accuracy: 0.9371
# Epoch 28/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4729 - accuracy: 0.8556 - val_loss: 0.2033 - val_accuracy: 0.9305
# Epoch 29/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4853 - accuracy: 0.8543 - val_loss: 0.2126 - val_accuracy: 0.9319
# Epoch 30/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4632 - accuracy: 0.8567 - val_loss: 0.2051 - val_accuracy: 0.9324
# Epoch 31/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4671 - accuracy: 0.8595 - val_loss: 0.2014 - val_accuracy: 0.9333
# Epoch 32/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4603 - accuracy: 0.8599 - val_loss: 0.2128 - val_accuracy: 0.9300
# Epoch 33/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4642 - accuracy: 0.8567 - val_loss: 0.2082 - val_accuracy: 0.9333
# Epoch 34/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4809 - accuracy: 0.8532 - val_loss: 0.2219 - val_accuracy: 0.9281
# Epoch 35/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4688 - accuracy: 0.8570 - val_loss: 0.2226 - val_accuracy: 0.9248
# Epoch 36/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4666 - accuracy: 0.8597 - val_loss: 0.2224 - val_accuracy: 0.9267
# Epoch 37/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4695 - accuracy: 0.8595 - val_loss: 0.2048 - val_accuracy: 0.9357
# Epoch 38/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4181 - accuracy: 0.8682 - val_loss: 0.2130 - val_accuracy: 0.9281
# Epoch 39/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4591 - accuracy: 0.8610 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 40/40
# 735/735 [==============================] - 36s 49ms/step - loss: 0.4286 - accuracy: 0.8660 - val_loss: 0.2099 - val_accuracy: 0.9305

# %% [markdown]
# ### Show history of traning and validation Accuracy

# %%
def summarize(history):
    
    plt.style.use("ggplot")
    fig, axes = plt.subplots(1,2,figsize=(16,6))

    #Plot loss     
    axes[0].set_title('Cross Entropy Loss')
    axes[0].plot(history.history['loss'], color='blue', label="Train")
    axes[0].plot(history.history['val_loss'], color='orange', label="Validation")
    axes[0].legend(loc='upper right')

    #Plot Accuracy 
    axes[1].set_title('Classification Accuracy')
    axes[1].plot(history.history['accuracy'], color='blue', label="Train")
    axes[1].plot(history.history['val_accuracy'], color='orange', label="Validation")
    axes[1].legend(loc='lower right')
    
    plt.show();
    pass

# %%
summarize(history)

# %% [markdown]
# ### Validation and Confusion Matrix

# %%
def show_conf_matrix(conf_mtx, classes, cmap=plt.cm.Blues):
    
    conf_mtx = conf_mtx.astype('float')/conf_mtx.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(20,20))
    plt.imshow(conf_mtx, interpolation='nearest', cmap=cmap)
    plt.title("Confusion Matrix")
    plt.colorbar()
    
    marks = np.arange(len(classes))
    plt.xticks(marks, classes,rotation=90)
    plt.yticks(marks, classes)
    
    fmrt = '.2f'
    limit = conf_mtx.max()/2.0   
    for i,j in itertools.product(range(conf_mtx.shape[0]), range(conf_mtx.shape[1])):
        plt.text(j,i, format(conf_mtx[i,j], fmrt),
                horizontalalignment = "center",
                color = "white" if conf_mtx[i,j] > limit else "black")
    
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.grid(None);

# %%
val_predict = model.predict(val_imgs)
val_predict = np.argmax(val_predict, axis=1)
val_predict.shape
# Out:
# (2100,)

# %%
val_actual = np.argmax(val_classes, axis=1)

conf_matrix = confusion_matrix(val_actual, val_predict)
np.set_printoptions(precision=2)

plt.figure()
show_conf_matrix(conf_matrix, classes=out_classes)
plt.grid(None)
plt.show()

# %% [markdown]
# ### Make Predictions

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
#Formula
# accuracy: (tp + tn) / (p + n)
InceptionResNetV2_Accuracy = accuracy_score(val_actual, val_predict)
print('InceptionResNetV2 - Validation Accuracy: %f' % InceptionResNetV2_Accuracy)

#Formula
# precision tp / (tp + fp)
InceptionResNetV2_precision = precision_score(val_actual, val_predict, average="weighted")
print('InceptionResNetV2 - Precision : %f' % InceptionResNetV2_precision)

#Formula
# recall: tp / (tp + fn)
InceptionResNetV2_recall = recall_score(val_actual, val_predict, average="weighted")
print('InceptionResNetV2 - Recall : %f' % InceptionResNetV2_recall)

#Formula
# f1: 2 tp / (2 tp + fp + fn)
InceptionResNetV2_f1_sc = f1_score(val_actual, val_predict, average="weighted")
print('InceptionResNetV2 - F1 score : %f' % InceptionResNetV2_f1_sc)
# Out:
# InceptionResNetV2 - Validation Accuracy: 0.930476
# InceptionResNetV2 - Precision : 0.932533
# InceptionResNetV2 - Recall : 0.930476
# InceptionResNetV2 - F1 score : 0.930614

# %%
_, model_base_acc = model.evaluate(
   test_imgs, test_classes, verbose=0)

print('Test accuracy for base:', model_base_acc)
# Out:
# Test accuracy for base: 0.9247618913650513

# %% [markdown]
# ### Save the model

# %%
#model.save("/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionResNetV2/InceptionResNetV2_New_baseline_01.h5")

# %%
InceptionResNetV2_base_fin = load_model('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionResNetV2/InceptionResNetV2_New_baseline_01.h5')

# %% [markdown]
# ### Calculate Inference time

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = InceptionResNetV2_base_fin.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
print("Inference time is: ", ir_time)
# Out:
# Predicted Class is: 1
# Inference time is:  0.07802118400013569

# %% [markdown]
# ## Model Pruning

# %%
# !pip install tensorflow_model_optimization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_model_optimization
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 14.4 MB/s
# Requirement already satisfied: numpy~=1.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (1.21.6)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (0.1.7)
# Requirement already satisfied: six~=1.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (1.15.0)
# Installing collected packages: tensorflow-model-optimization
# Successfully installed tensorflow-model-optimization-0.7.3

# %%
import tensorflow_model_optimization as tfmot
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
# Compute end step to finish pruning after 2 epochs.
batch_size = 10
epochs = 30

end_step = np.ceil(train_imgs.shape[0]//batch_size).astype(np.int32) * epochs

# Define model for pruning.
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.20,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=end_step)
}

model_for_pruning = prune_low_magnitude(model, **pruning_params)
# `prune_low_magnitude` requires a recompile.
model_for_pruning.compile(optimizer='adam',
              # loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model_for_pruning.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  prune_low_magnitude_conv2d (Pr  (None, 111, 111, 32  1730       ['input_1[0][0]']
#  uneLowMagnitude)               )
#
#  prune_low_magnitude_batch_norm  (None, 111, 111, 32  97         ['prune_low_magnitude_conv2d[0][0
#  alization (PruneLowMagnitude)  )                                ]']
#
#  prune_low_magnitude_activation  (None, 111, 111, 32  1          ['prune_low_magnitude_batch_norma
#   (PruneLowMagnitude)           )                                lization[0][0]']
#
#  prune_low_magnitude_conv2d_1 (  (None, 109, 109, 32  18434      ['prune_low_magnitude_activation[
#  PruneLowMagnitude)             )                                0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 109, 109, 32  97         ['prune_low_magnitude_conv2d_1[0]
#  alization_1 (PruneLowMagnitude  )                               [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 109, 109, 32  1          ['prune_low_magnitude_batch_norma
#  _1 (PruneLowMagnitude)         )                                lization_1[0][0]']
#
#  prune_low_magnitude_conv2d_2 (  (None, 109, 109, 64  36866      ['prune_low_magnitude_activation_
#  PruneLowMagnitude)             )                                1[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 109, 109, 64  193        ['prune_low_magnitude_conv2d_2[0]
#  alization_2 (PruneLowMagnitude  )                               [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 109, 109, 64  1          ['prune_low_magnitude_batch_norma
#  _2 (PruneLowMagnitude)         )                                lization_2[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 54, 54, 64)  1           ['prune_low_magnitude_activation_
#  g2d (PruneLowMagnitude)                                         2[0][0]']
#
#  prune_low_magnitude_conv2d_3 (  (None, 54, 54, 80)  10242       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 54, 54, 80)  241         ['prune_low_magnitude_conv2d_3[0]
#  alization_3 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 54, 54, 80)  1           ['prune_low_magnitude_batch_norma
#  _3 (PruneLowMagnitude)                                          lization_3[0][0]']
#
#  prune_low_magnitude_conv2d_4 (  (None, 52, 52, 192)  276482     ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              3[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 52, 52, 192)  577        ['prune_low_magnitude_conv2d_4[0]
#  alization_4 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 52, 52, 192)  1          ['prune_low_magnitude_batch_norma
#  _4 (PruneLowMagnitude)                                          lization_4[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 25, 25, 192)  1          ['prune_low_magnitude_activation_
#  g2d_1 (PruneLowMagnitude)                                       4[0][0]']
#
#  prune_low_magnitude_conv2d_8 (  (None, 25, 25, 64)  24578       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d_1[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_8[0]
#  alization_8 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _8 (PruneLowMagnitude)                                          lization_8[0][0]']
#
#  prune_low_magnitude_conv2d_6 (  (None, 25, 25, 48)  18434       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d_1[0][0]']
#
#  prune_low_magnitude_conv2d_9 (  (None, 25, 25, 96)  110594      ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              8[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_6[0]
#  alization_6 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_9[0]
#  alization_9 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _6 (PruneLowMagnitude)                                          lization_6[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _9 (PruneLowMagnitude)                                          lization_9[0][0]']
#
#  prune_low_magnitude_average_po  (None, 25, 25, 192)  1          ['prune_low_magnitude_max_pooling
#  oling2d (PruneLowMagnitude)                                     2d_1[0][0]']
#
#  prune_low_magnitude_conv2d_5 (  (None, 25, 25, 96)  36866       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d_1[0][0]']
#
#  prune_low_magnitude_conv2d_7 (  (None, 25, 25, 64)  153602      ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              6[0][0]']
#
#  prune_low_magnitude_conv2d_10   (None, 25, 25, 96)  165890      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             9[0][0]']
#
#  prune_low_magnitude_conv2d_11   (None, 25, 25, 64)  24578       ['prune_low_magnitude_average_poo
#  (PruneLowMagnitude)                                             ling2d[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_5[0]
#  alization_5 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_7[0]
#  alization_7 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_10[0
#  alization_10 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_11[0
#  alization_11 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _5 (PruneLowMagnitude)                                          lization_5[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _7 (PruneLowMagnitude)                                          lization_7[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _10 (PruneLowMagnitude)                                         lization_10[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _11 (PruneLowMagnitude)                                         lization_11[0][0]']
#
#  prune_low_magnitude_mixed_5b (  (None, 25, 25, 320)  1          ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              5[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  7[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  10[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  11[0][0]']
#
#  prune_low_magnitude_conv2d_15   (None, 25, 25, 32)  20482       ['prune_low_magnitude_mixed_5b[0]
#  (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_15[0
#  alization_15 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _15 (PruneLowMagnitude)                                         lization_15[0][0]']
#
#  prune_low_magnitude_conv2d_13   (None, 25, 25, 32)  20482       ['prune_low_magnitude_mixed_5b[0]
#  (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d_16   (None, 25, 25, 48)  27650       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             15[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_13[0
#  alization_13 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_16[0
#  alization_16 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _13 (PruneLowMagnitude)                                         lization_13[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _16 (PruneLowMagnitude)                                         lization_16[0][0]']
#
#  prune_low_magnitude_conv2d_12   (None, 25, 25, 32)  20482       ['prune_low_magnitude_mixed_5b[0]
#  (PruneLowMagnitude)                                             [0]']
#
#  prune_low_magnitude_conv2d_14   (None, 25, 25, 32)  18434       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             13[0][0]']
#
#  prune_low_magnitude_conv2d_17   (None, 25, 25, 64)  55298       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             16[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_12[0
#  alization_12 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_14[0
#  alization_14 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_17[0
#  alization_17 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _12 (PruneLowMagnitude)                                         lization_12[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _14 (PruneLowMagnitude)                                         lization_14[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _17 (PruneLowMagnitude)                                         lization_17[0][0]']
#
#  prune_low_magnitude_block35_1_  (None, 25, 25, 128)  1          ['prune_low_magnitude_activation_
#  mixed (PruneLowMagnitude)                                       12[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  14[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  17[0][0]']
#
#  prune_low_magnitude_block35_1_  (None, 25, 25, 320)  82242      ['prune_low_magnitude_block35_1_m
#  conv (PruneLowMagnitude)                                        ixed[0][0]']
#
#  prune_low_magnitude_block35_1   (None, 25, 25, 320)  1          ['prune_low_magnitude_mixed_5b[0]
#  (PruneLowMagnitude)                                             [0]',
#                                                                   'prune_low_magnitude_block35_1_c
#                                                                  onv[0][0]']
#
#  prune_low_magnitude_block35_1_  (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_1[0
#  ac (PruneLowMagnitude)                                          ][0]']
#
#  prune_low_magnitude_conv2d_21   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_1_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_21[0
#  alization_21 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _21 (PruneLowMagnitude)                                         lization_21[0][0]']
#
#  prune_low_magnitude_conv2d_19   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_1_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_22   (None, 25, 25, 48)  27650       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             21[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_19[0
#  alization_19 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_22[0
#  alization_22 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _19 (PruneLowMagnitude)                                         lization_19[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _22 (PruneLowMagnitude)                                         lization_22[0][0]']
#
#  prune_low_magnitude_conv2d_18   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_1_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_20   (None, 25, 25, 32)  18434       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             19[0][0]']
#
#  prune_low_magnitude_conv2d_23   (None, 25, 25, 64)  55298       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             22[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_18[0
#  alization_18 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_20[0
#  alization_20 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_23[0
#  alization_23 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _18 (PruneLowMagnitude)                                         lization_18[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _20 (PruneLowMagnitude)                                         lization_20[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _23 (PruneLowMagnitude)                                         lization_23[0][0]']
#
#  prune_low_magnitude_block35_2_  (None, 25, 25, 128)  1          ['prune_low_magnitude_activation_
#  mixed (PruneLowMagnitude)                                       18[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  20[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  23[0][0]']
#
#  prune_low_magnitude_block35_2_  (None, 25, 25, 320)  82242      ['prune_low_magnitude_block35_2_m
#  conv (PruneLowMagnitude)                                        ixed[0][0]']
#
#  prune_low_magnitude_block35_2   (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_1_a
#  (PruneLowMagnitude)                                             c[0][0]',
#                                                                   'prune_low_magnitude_block35_2_c
#                                                                  onv[0][0]']
#
#  prune_low_magnitude_block35_2_  (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_2[0
#  ac (PruneLowMagnitude)                                          ][0]']
#
#  prune_low_magnitude_conv2d_27   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_2_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_27[0
#  alization_27 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _27 (PruneLowMagnitude)                                         lization_27[0][0]']
#
#  prune_low_magnitude_conv2d_25   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_2_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_28   (None, 25, 25, 48)  27650       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             27[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_25[0
#  alization_25 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_28[0
#  alization_28 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _25 (PruneLowMagnitude)                                         lization_25[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _28 (PruneLowMagnitude)                                         lization_28[0][0]']
#
#  prune_low_magnitude_conv2d_24   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_2_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_26   (None, 25, 25, 32)  18434       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             25[0][0]']
#
#  prune_low_magnitude_conv2d_29   (None, 25, 25, 64)  55298       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             28[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_24[0
#  alization_24 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_26[0
#  alization_26 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_29[0
#  alization_29 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _24 (PruneLowMagnitude)                                         lization_24[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _26 (PruneLowMagnitude)                                         lization_26[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _29 (PruneLowMagnitude)                                         lization_29[0][0]']
#
#  prune_low_magnitude_block35_3_  (None, 25, 25, 128)  1          ['prune_low_magnitude_activation_
#  mixed (PruneLowMagnitude)                                       24[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  26[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  29[0][0]']
#
#  prune_low_magnitude_block35_3_  (None, 25, 25, 320)  82242      ['prune_low_magnitude_block35_3_m
#  conv (PruneLowMagnitude)                                        ixed[0][0]']
#
#  prune_low_magnitude_block35_3   (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_2_a
#  (PruneLowMagnitude)                                             c[0][0]',
#                                                                   'prune_low_magnitude_block35_3_c
#                                                                  onv[0][0]']
#
#  prune_low_magnitude_block35_3_  (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_3[0
#  ac (PruneLowMagnitude)                                          ][0]']
#
#  prune_low_magnitude_conv2d_33   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_3_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_33[0
#  alization_33 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _33 (PruneLowMagnitude)                                         lization_33[0][0]']
#
#  prune_low_magnitude_conv2d_31   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_3_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_34   (None, 25, 25, 48)  27650       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             33[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_31[0
#  alization_31 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_34[0
#  alization_34 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _31 (PruneLowMagnitude)                                         lization_31[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _34 (PruneLowMagnitude)                                         lization_34[0][0]']
#
#  prune_low_magnitude_conv2d_30   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_3_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_32   (None, 25, 25, 32)  18434       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             31[0][0]']
#
#  prune_low_magnitude_conv2d_35   (None, 25, 25, 64)  55298       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             34[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_30[0
#  alization_30 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_32[0
#  alization_32 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_35[0
#  alization_35 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _30 (PruneLowMagnitude)                                         lization_30[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _32 (PruneLowMagnitude)                                         lization_32[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _35 (PruneLowMagnitude)                                         lization_35[0][0]']
#
#  prune_low_magnitude_block35_4_  (None, 25, 25, 128)  1          ['prune_low_magnitude_activation_
#  mixed (PruneLowMagnitude)                                       30[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  32[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  35[0][0]']
#
#  prune_low_magnitude_block35_4_  (None, 25, 25, 320)  82242      ['prune_low_magnitude_block35_4_m
#  conv (PruneLowMagnitude)                                        ixed[0][0]']
#
#  prune_low_magnitude_block35_4   (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_3_a
#  (PruneLowMagnitude)                                             c[0][0]',
#                                                                   'prune_low_magnitude_block35_4_c
#                                                                  onv[0][0]']
#
#  prune_low_magnitude_block35_4_  (None, 25, 25, 320)  1          ['prune_low_magnitude_block35_4[0
#  ac (PruneLowMagnitude)                                          ][0]']
#
#  prune_low_magnitude_conv2d_39   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_4_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_39[0
#  alization_39 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _39 (PruneLowMagnitude)                                         lization_39[0][0]']
#
#  prune_low_magnitude_conv2d_37   (None, 25, 25, 32)  20482       ['prune_low_magnitude_block35_4_a
#  (PruneLowMagnitude)                                             c[0][0]']
#
#  prune_low_magnitude_conv2d_40   (None, 25, 25, 48)  27650       ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             39[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_37[0
#  alization_37 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_40[0
#  alization_40 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _37 (PruneLowMagnitude)                                         lization_37[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _40 (PruneLowMagnitude)                                         lization_40[0][0]']
# ...
#  prune_low_magnitude_batch_norm  (None, 5, 5, 256)   769         ['prune_low_magnitude_conv2d_194[
#  alization_194 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _191 (PruneLowMagnitude)                                        lization_191[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 256)   1           ['prune_low_magnitude_batch_norma
#  _194 (PruneLowMagnitude)                                        lization_194[0][0]']
#
#  prune_low_magnitude_block8_8_m  (None, 5, 5, 448)   1           ['prune_low_magnitude_activation_
#  ixed (PruneLowMagnitude)                                        191[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  194[0][0]']
#
#  prune_low_magnitude_block8_8_c  (None, 5, 5, 2080)  1865762     ['prune_low_magnitude_block8_8_mi
#  onv (PruneLowMagnitude)                                         xed[0][0]']
#
#  prune_low_magnitude_block8_8 (  (None, 5, 5, 2080)  1           ['prune_low_magnitude_block8_7_ac
#  PruneLowMagnitude)                                              [0][0]',
#                                                                   'prune_low_magnitude_block8_8_co
#                                                                  nv[0][0]']
#
#  prune_low_magnitude_block8_8_a  (None, 5, 5, 2080)  1           ['prune_low_magnitude_block8_8[0]
#  c (PruneLowMagnitude)                                           [0]']
#
#  prune_low_magnitude_conv2d_196  (None, 5, 5, 192)   798722      ['prune_low_magnitude_block8_8_ac
#   (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 192)   577         ['prune_low_magnitude_conv2d_196[
#  alization_196 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _196 (PruneLowMagnitude)                                        lization_196[0][0]']
#
#  prune_low_magnitude_conv2d_197  (None, 5, 5, 224)   258050      ['prune_low_magnitude_activation_
#   (PruneLowMagnitude)                                            196[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 224)   673         ['prune_low_magnitude_conv2d_197[
#  alization_197 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 224)   1           ['prune_low_magnitude_batch_norma
#  _197 (PruneLowMagnitude)                                        lization_197[0][0]']
#
#  prune_low_magnitude_conv2d_195  (None, 5, 5, 192)   798722      ['prune_low_magnitude_block8_8_ac
#   (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_conv2d_198  (None, 5, 5, 256)   344066      ['prune_low_magnitude_activation_
#   (PruneLowMagnitude)                                            197[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 192)   577         ['prune_low_magnitude_conv2d_195[
#  alization_195 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 256)   769         ['prune_low_magnitude_conv2d_198[
#  alization_198 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _195 (PruneLowMagnitude)                                        lization_195[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 256)   1           ['prune_low_magnitude_batch_norma
#  _198 (PruneLowMagnitude)                                        lization_198[0][0]']
#
#  prune_low_magnitude_block8_9_m  (None, 5, 5, 448)   1           ['prune_low_magnitude_activation_
#  ixed (PruneLowMagnitude)                                        195[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  198[0][0]']
#
#  prune_low_magnitude_block8_9_c  (None, 5, 5, 2080)  1865762     ['prune_low_magnitude_block8_9_mi
#  onv (PruneLowMagnitude)                                         xed[0][0]']
#
#  prune_low_magnitude_block8_9 (  (None, 5, 5, 2080)  1           ['prune_low_magnitude_block8_8_ac
#  PruneLowMagnitude)                                              [0][0]',
#                                                                   'prune_low_magnitude_block8_9_co
#                                                                  nv[0][0]']
#
#  prune_low_magnitude_block8_9_a  (None, 5, 5, 2080)  1           ['prune_low_magnitude_block8_9[0]
#  c (PruneLowMagnitude)                                           [0]']
#
#  prune_low_magnitude_conv2d_200  (None, 5, 5, 192)   798722      ['prune_low_magnitude_block8_9_ac
#   (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 192)   577         ['prune_low_magnitude_conv2d_200[
#  alization_200 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _200 (PruneLowMagnitude)                                        lization_200[0][0]']
#
#  prune_low_magnitude_conv2d_201  (None, 5, 5, 224)   258050      ['prune_low_magnitude_activation_
#   (PruneLowMagnitude)                                            200[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 224)   673         ['prune_low_magnitude_conv2d_201[
#  alization_201 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 224)   1           ['prune_low_magnitude_batch_norma
#  _201 (PruneLowMagnitude)                                        lization_201[0][0]']
#
#  prune_low_magnitude_conv2d_199  (None, 5, 5, 192)   798722      ['prune_low_magnitude_block8_9_ac
#   (PruneLowMagnitude)                                            [0][0]']
#
#  prune_low_magnitude_conv2d_202  (None, 5, 5, 256)   344066      ['prune_low_magnitude_activation_
#   (PruneLowMagnitude)                                            201[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 192)   577         ['prune_low_magnitude_conv2d_199[
#  alization_199 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 256)   769         ['prune_low_magnitude_conv2d_202[
#  alization_202 (PruneLowMagnitu                                  0][0]']
#  de)
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _199 (PruneLowMagnitude)                                        lization_199[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 256)   1           ['prune_low_magnitude_batch_norma
#  _202 (PruneLowMagnitude)                                        lization_202[0][0]']
#
#  prune_low_magnitude_block8_10_  (None, 5, 5, 448)   1           ['prune_low_magnitude_activation_
#  mixed (PruneLowMagnitude)                                       199[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  202[0][0]']
#
#  prune_low_magnitude_block8_10_  (None, 5, 5, 2080)  1865762     ['prune_low_magnitude_block8_10_m
#  conv (PruneLowMagnitude)                                        ixed[0][0]']
#
#  prune_low_magnitude_block8_10   (None, 5, 5, 2080)  1           ['prune_low_magnitude_block8_9_ac
#  (PruneLowMagnitude)                                             [0][0]',
#                                                                   'prune_low_magnitude_block8_10_c
#                                                                  onv[0][0]']
#
#  prune_low_magnitude_conv_7b (P  (None, 5, 5, 1536)  6389762     ['prune_low_magnitude_block8_10[0
#  runeLowMagnitude)                                               ][0]']
#
#  prune_low_magnitude_conv_7b_bn  (None, 5, 5, 1536)  4609        ['prune_low_magnitude_conv_7b[0][
#   (PruneLowMagnitude)                                            0]']
#
#  prune_low_magnitude_conv_7b_ac  (None, 5, 5, 1536)  1           ['prune_low_magnitude_conv_7b_bn[
#   (PruneLowMagnitude)                                            0][0]']
#
#  prune_low_magnitude_global_ave  (None, 1536)        1           ['prune_low_magnitude_conv_7b_ac[
#  rage_pooling2d (PruneLowMagnit                                  0][0]']
#  ude)
#
#  prune_low_magnitude_dropout (P  (None, 1536)        1           ['prune_low_magnitude_global_aver
#  runeLowMagnitude)                                               age_pooling2d[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 1536)        6145        ['prune_low_magnitude_dropout[0][
#  alization_203 (PruneLowMagnitu                                  0]']
#  de)
#
#  prune_low_magnitude_dense (Pru  (None, 21)          64535       ['prune_low_magnitude_batch_norma
#  neLowMagnitude)                                                 lization_203[0][0]']
#
# ==================================================================================================
# Total params: 108,608,601
# Trainable params: 35,349
# Non-trainable params: 108,573,252
# __________________________________________________________________________________________________

# %%
logdir = tempfile.mkdtemp()

callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep(),
  tfmot.sparsity.keras.PruningSummaries(log_dir=logdir),
]
  
model_for_pruning.fit(train_imgs, train_classes,
                      steps_per_epoch=len(train_imgs)//10,
                      epochs=10, 
                      verbose=1,
                      validation_data=(val_imgs,val_classes),
                      validation_steps=len(val_imgs)//10)
                      # callbacks=callbacks)
# Out:
# Epoch 1/10
# 735/735 [==============================] - 178s 242ms/step - loss: 0.4689 - accuracy: 0.8536 - val_loss: 0.2307 - val_accuracy: 0.9286
# Epoch 2/10
# 735/735 [==============================] - 164s 222ms/step - loss: 0.5117 - accuracy: 0.8424 - val_loss: 0.2602 - val_accuracy: 0.9224
# Epoch 3/10
# 735/735 [==============================] - 165s 225ms/step - loss: 0.5388 - accuracy: 0.8348 - val_loss: 0.3030 - val_accuracy: 0.9086
# Epoch 4/10
# 735/735 [==============================] - 165s 225ms/step - loss: 0.6259 - accuracy: 0.8146 - val_loss: 0.3030 - val_accuracy: 0.9110
# Epoch 5/10
# 735/735 [==============================] - 166s 226ms/step - loss: 0.6590 - accuracy: 0.8050 - val_loss: 0.3381 - val_accuracy: 0.8990
# Epoch 6/10
# 735/735 [==============================] - 166s 226ms/step - loss: 0.7043 - accuracy: 0.7887 - val_loss: 0.3528 - val_accuracy: 0.8971
# Epoch 7/10
# 735/735 [==============================] - 164s 223ms/step - loss: 0.8307 - accuracy: 0.7517 - val_loss: 0.4075 - val_accuracy: 0.8762
# Epoch 8/10
# 735/735 [==============================] - 163s 221ms/step - loss: 0.9757 - accuracy: 0.7184 - val_loss: 0.4304 - val_accuracy: 0.8648
# Epoch 9/10
# 735/735 [==============================] - 165s 224ms/step - loss: 1.0954 - accuracy: 0.6767 - val_loss: 0.5226 - val_accuracy: 0.8319
# Epoch 10/10
# 735/735 [==============================] - 165s 225ms/step - loss: 1.2303 - accuracy: 0.6336 - val_loss: 0.5592 - val_accuracy: 0.8214

# %%
_, model_prun_acc = model_for_pruning.evaluate(
   test_imgs, test_classes, verbose=0)

print('Test accuracy for base model:', model_base_acc) 
print('Test accuracy for Prunned model:', model_prun_acc)
# Out:
# Test accuracy for base model: 0.9247618913650513
# Test accuracy for Prunned model: 0.8333333134651184

# %%
# model_for_pruning.save('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionResNetV2/model_for_pruning_01.h5')

# %%
# model_for_pruning = load_model('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionResNetV2/model_for_pruning_01.h5')

# %%
val_pred_prun = model_for_pruning.predict(val_imgs)
val_pred_prun = np.argmax(val_pred_prun, axis=1)
val_pred_prun.shape
# Out:
# (2100,)

# %%
val_actual = np.argmax(val_classes, axis=1)

cnf_mat = confusion_matrix(val_actual, val_pred_prun)
np.set_printoptions(precision=2)

plt.figure()
show_conf_matrix(cnf_mat, classes=out_classes)
plt.grid(None)
plt.show();

# %% [markdown]
# ### Model Prediction Accuracy

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
#Formula
# accuracy: (tp + tn) / (p + n)
InceptionResNetV2_Accuracy_prun = accuracy_score(val_actual, val_pred_prun)
print('Pruning InceptionResNetV2 - Validation Accuracy: %f' % InceptionResNetV2_Accuracy_prun)

#Formula
# precision tp / (tp + fp)
InceptionResNetV2_precision_prun = precision_score(val_actual, val_pred_prun, average="weighted")
print('Pruning InceptionResNetV2 - Precision : %f' % InceptionResNetV2_precision_prun)

#Formula
# recall: tp / (tp + fn)
InceptionResNetV2_recall_prun = recall_score(val_actual, val_pred_prun, average="weighted")
print('Pruning InceptionResNetV2 - Recall : %f' % InceptionResNetV2_recall_prun)

#Formula
# f1: 2 tp / (2 tp + fp + fn)
InceptionResNetV2_f1_sc_prun = f1_score(val_actual, val_pred_prun, average="weighted")
print('Pruning InceptionResNetV2 - F1 score : %f' % InceptionResNetV2_f1_sc_prun)
# Out:
# Pruning InceptionResNetV2 - Validation Accuracy: 0.821429
# Pruning InceptionResNetV2 - Precision : 0.825362
# Pruning InceptionResNetV2 - Recall : 0.821429
# Pruning InceptionResNetV2 - F1 score : 0.820658

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = model_for_pruning.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
print("Inference time is: ", ir_time)
# Out:
# Predicted Class is: 3
# Inference time is:  0.07628494700111332

# %% [markdown]
# ### Grad-CAM Visual on Baseline Model

# %%
def grad_cam_heatmap(pred_img, model, lst_conv_layer, pred_index=None):
    #Created a model which maps the input image to activations of last conv layer and output predictions
    gradient_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(lst_conv_layer).output, model.output]
    )

    #Calculate gradient of top predicted class for input image for last conv layer activation
    with tf.GradientTape() as tape:
        lst_conv_layer_out, preds = gradient_model(pred_img)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channels = preds[:, pred_index]

    # Gradient of top predicted for output feature map of last conv layer
    grads = tape.gradient(class_channels, lst_conv_layer_out)

    # A vector of mean intensity of the gradient over feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Multipled each channel in the feature map array to check importance of channel 
    # with respect to top predicted class and sum of all channel to get heatmap of class activation
    lst_conv_layer_out = lst_conv_layer_out[0]
    heatmap = lst_conv_layer_out @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    #Normalize a heatmap between 0 and 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def grad_cam_display(org_img_path, heatmap, grad_cam_path="grad_cam.jpg", alpha=0.4):
    # Load an image
    img = tf.keras.preprocessing.image.load_img(org_img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to 0-255 range
    heatmap = np.uint8(255 * heatmap)

    # color heatmap using jet colourmap
    jet = cm.get_cmap("jet")

    # Use RGB colormap values
    jet_colors = jet(np.arange(256))[:, :3]
    jet_color_heatmap = jet_colors[heatmap]

    # Created an image with RGB colored heatmap
    jet_color_heatmap = tf.keras.preprocessing.image.array_to_img(jet_color_heatmap)
    jet_color_heatmap = jet_color_heatmap.resize((img.shape[1], img.shape[0]))
    jet_color_heatmap = tf.keras.preprocessing.image.img_to_array(jet_color_heatmap)

    # Superimpose a heatmap on actual image
    superimposed_img = jet_color_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)

    superimposed_img.save(grad_cam_path)

    # Display Grad CAM
    # display(Image(grad_cam_path))
    
    return grad_cam_path
    
preprocess_input = tf.keras.applications.inception_resnet_v2.preprocess_input
decode_predictions = tf.keras.applications.inception_resnet_v2.decode_predictions

lst_conv_layer = "conv_7b_ac"
img_size = (224,224)

# Remove last layer's softmax
InceptionResNetV2_base_fin.layers[-1].activation = None

# %% [markdown]
# ### Visualise image

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 
import matplotlib.cm as cm

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = InceptionResNetV2_base_fin.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
# print("Inference time is: ", ir_time)

img_path = '/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model'

# Calculate Grad-CAM class activation
gc_heatmap = grad_cam_heatmap(pred_img, InceptionResNetV2_base_fin, lst_conv_layer)
# print(heatmap)
g_cam_path = grad_cam_display('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif', gc_heatmap)
img = plt.imread(g_cam_path)
img = plt.imshow(img)

print("\n\nGrad-CAM Visual")
print("Predicted Class is:", pre_class[0])
# Out:
# Predicted Class is: 1
#
#
# Grad-CAM Visual
# Predicted Class is: 1
