# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os, cv2, json, itertools, tempfile
from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dropout, BatchNormalization, GlobalAveragePooling2D, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from google.colab import drive
from tensorflow import keras
from keras.models import load_model
# %load_ext tensorboard

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
g_path = '/content/gdrive'
image_path = g_path + '/My Drive/Colab Notebooks' + '/archive'
image_dir_list = os.listdir(image_path)

print(image_dir_list)
# Out:
# ['readme.txt', 'label_map.json', 'test.csv', 'validation.csv', 'train.csv', 'images_train_test_val', 'images']

# %% [markdown]
# ### Analyse the data and classes

# %%
im_dataset_path = image_path + "/images"
json_file_path = image_path + "/label_map.json"

with open(json_file_path,"r") as j_file:
    class_name_cats = json.load(j_file)

len_classes = len(class_name_cats)
out_classes = list(class_name_cats.keys())
class_name_cats
# Out:
# {'agricultural': 0,
#  'airplane': 1,
#  'baseballdiamond': 2,
#  'beach': 3,
#  'buildings': 4,
#  'chaparral': 5,
#  'denseresidential': 6,
#  'forest': 7,
#  'freeway': 8,
#  'golfcourse': 9,
#  'intersection': 10,
#  'mediumresidential': 11,
#  'mobilehomepark': 12,
#  'overpass': 13,
#  'parkinglot': 14,
#  'river': 15,
#  'runway': 16,
#  'sparseresidential': 17,
#  'storagetanks': 18,
#  'tenniscourt': 19,
#  'harbor': 20}

# %% [markdown]
# ### Load image dataset

# %%
def load_image_data(csv_file):
    images_arr = []
    labels_arr = []
    img_csv = pd.read_csv(csv_file,index_col="Unnamed: 0")

    for i in tqdm(range(img_csv.shape[0])):
        image_name = img_csv.loc[i,'Filename']
        image = load_img(os.path.join(im_dataset_path,image_name),target_size=(224,224))

        image = img_to_array(image)
        image = preprocess_input(image)
        label = img_csv.loc[i,'Label']
        
        images_arr.append(image)
        labels_arr.append(label)
    
    images_arr = np.array(images_arr)
    labels_arr = np.array(labels_arr)
    return images_arr, labels_arr

# %%
train_im_path = image_path + "/train.csv"
val_im_path = image_path + "/validation.csv"
test_im_path = image_path + "/test.csv"
 
train_imgs, train_classes = load_image_data(train_im_path)
val_imgs, val_classes = load_image_data(val_im_path)
test_imgs, test_classes = load_image_data(test_im_path)

train_imgs.shape, train_classes.shape, val_imgs.shape, val_classes.shape, test_imgs.shape, test_classes.shape
# Out:
# 100%|██████████| 7350/7350 [00:28<00:00, 262.27it/s]
# 100%|██████████| 2100/2100 [00:07<00:00, 278.88it/s]
# 100%|██████████| 1050/1050 [00:03<00:00, 290.75it/s]
# ((7350, 224, 224, 3),
#  (7350,),
#  (2100, 224, 224, 3),
#  (2100,),
#  (1050, 224, 224, 3),
#  (1050,))

# %%
train_classes = to_categorical(train_classes)
val_classes = to_categorical(val_classes)
test_classes = to_categorical(test_classes)

print(train_classes.shape)
print(val_classes.shape)
print(test_classes.shape)
# Out:
# (7350, 21)
# (2100, 21)
# (1050, 21)

# %% [markdown]
# ### InceptionNetV3 Model

# %%
InceptionV3_model = tf.keras.applications.InceptionV3(weights='imagenet',input_shape=(224, 224, 3),include_top=False)

InceptionV3_model.trainable = False

# Add pooling layer
inputs = InceptionV3_model.output
inputs = GlobalAveragePooling2D()(inputs)

# Add dropout layer
inputs = Dropout(0.5)(inputs)

# Add Softmax Layer for outputs classes
preds = Dense(21, activation='softmax')(inputs)
model = Model(inputs=InceptionV3_model.input, outputs=preds)

# %% [markdown]
# ### Compile Model

# %%
# Compile Model
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Plot Model network

# %%
# plot_model(model,to_file='MobileNet_transfer_model.png',show_shapes=True,show_layer_names=True)
# SVG(model_to_dot(model).create(prog='dot',format='svg'))

# %% [markdown]
# ### Train Model

# %%
epochs = 20
batchSize = 10

history = model.fit(train_imgs, train_classes,
                      steps_per_epoch=len(train_imgs)//batchSize,
                      epochs=epochs,
                      verbose=1,
                      validation_data=(val_imgs, val_classes),
                      validation_steps=len(val_imgs)//batchSize)
                      # callbacks=[MobileNet_checkpoint, MobileNet_logs])
# Out:
# Epoch 1/20
# 735/735 [==============================] - 37s 41ms/step - loss: 1.1199 - accuracy: 0.6663 - val_loss: 0.4573 - val_accuracy: 0.8514
# Epoch 2/20
# 735/735 [==============================] - 28s 38ms/step - loss: 0.4925 - accuracy: 0.8410 - val_loss: 0.3915 - val_accuracy: 0.8729
# Epoch 3/20
# 735/735 [==============================] - 28s 38ms/step - loss: 0.4063 - accuracy: 0.8673 - val_loss: 0.3494 - val_accuracy: 0.8848
# Epoch 4/20
# 735/735 [==============================] - 28s 39ms/step - loss: 0.3444 - accuracy: 0.8873 - val_loss: 0.3510 - val_accuracy: 0.8948
# Epoch 5/20
# 735/735 [==============================] - 29s 39ms/step - loss: 0.3125 - accuracy: 0.8948 - val_loss: 0.3407 - val_accuracy: 0.8871
# Epoch 6/20
# 735/735 [==============================] - 29s 39ms/step - loss: 0.3177 - accuracy: 0.8935 - val_loss: 0.2902 - val_accuracy: 0.9090
# Epoch 7/20
# 735/735 [==============================] - 29s 39ms/step - loss: 0.2932 - accuracy: 0.9004 - val_loss: 0.3837 - val_accuracy: 0.8881
# Epoch 8/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2973 - accuracy: 0.9079 - val_loss: 0.3589 - val_accuracy: 0.8957
# Epoch 9/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2839 - accuracy: 0.9120 - val_loss: 0.3087 - val_accuracy: 0.9071
# Epoch 10/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2815 - accuracy: 0.9060 - val_loss: 0.3373 - val_accuracy: 0.9062
# Epoch 11/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2842 - accuracy: 0.9064 - val_loss: 0.3011 - val_accuracy: 0.9110
# Epoch 12/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2726 - accuracy: 0.9143 - val_loss: 0.3258 - val_accuracy: 0.9086
# Epoch 13/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2729 - accuracy: 0.9140 - val_loss: 0.2860 - val_accuracy: 0.9171
# Epoch 14/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2640 - accuracy: 0.9189 - val_loss: 0.2825 - val_accuracy: 0.9195
# Epoch 15/20
# 735/735 [==============================] - 30s 40ms/step - loss: 0.2705 - accuracy: 0.9136 - val_loss: 0.3121 - val_accuracy: 0.9038
# Epoch 16/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2959 - accuracy: 0.9109 - val_loss: 0.3070 - val_accuracy: 0.9152
# Epoch 17/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2623 - accuracy: 0.9197 - val_loss: 0.2978 - val_accuracy: 0.9148
# Epoch 18/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2588 - accuracy: 0.9226 - val_loss: 0.3386 - val_accuracy: 0.9071
# Epoch 19/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2540 - accuracy: 0.9229 - val_loss: 0.3996 - val_accuracy: 0.9010
# Epoch 20/20
# 735/735 [==============================] - 29s 40ms/step - loss: 0.2590 - accuracy: 0.9261 - val_loss: 0.3630 - val_accuracy: 0.9086

# %% [markdown]
# ### Show history of traning and validation Accuracy

# %%
def summarize(history):
    
    plt.style.use("ggplot")
    fig, axes = plt.subplots(1,2,figsize=(16,6))

    #Plot loss     
    axes[0].set_title('Cross Entropy Loss')
    axes[0].plot(history.history['loss'], color='blue', label="Train")
    axes[0].plot(history.history['val_loss'], color='orange', label="Validation")
    axes[0].legend(loc='upper right')

    #Plot Accuracy 
    axes[1].set_title('Classification Accuracy')
    axes[1].plot(history.history['accuracy'], color='blue', label="Train")
    axes[1].plot(history.history['val_accuracy'], color='orange', label="Validation")
    axes[1].legend(loc='lower right')
    
    plt.show();
    pass

# %%
summarize(history)

# %% [markdown]
# ### Validation and Confusion Matrix

# %%
def show_conf_matrix(conf_mtx, classes, cmap=plt.cm.Blues):
    
    conf_mtx = conf_mtx.astype('float')/conf_mtx.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(20,20))
    plt.imshow(conf_mtx, interpolation='nearest', cmap=cmap)
    plt.title("Confusion Matrix")
    plt.colorbar()
    
    marks = np.arange(len(classes))
    plt.xticks(marks, classes,rotation=90)
    plt.yticks(marks, classes)
    
    fmrt = '.2f'
    limit = conf_mtx.max()/2.0   
    for i,j in itertools.product(range(conf_mtx.shape[0]), range(conf_mtx.shape[1])):
        plt.text(j,i, format(conf_mtx[i,j], fmrt),
                horizontalalignment = "center",
                color = "white" if conf_mtx[i,j] > limit else "black")
    
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.grid(None);

# %%
val_predict = model.predict(val_imgs)
val_predict = np.argmax(val_predict, axis=1)
val_predict.shape
# Out:
# (2100,)

# %%
val_actual = np.argmax(val_classes, axis=1)

conf_matrix = confusion_matrix(val_actual, val_predict)
np.set_printoptions(precision=2)

plt.figure()
show_conf_matrix(conf_matrix, classes=out_classes)
plt.grid(None)
plt.show()

# %% [markdown]
# ### Make Predictions

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
#Formula
# accuracy: (tp + tn) / (p + n)
InceptionNetV3_Accuracy = accuracy_score(val_actual, val_predict)
print('InceptionNetV3 - Validation Accuracy: %f' % InceptionNetV3_Accuracy)

#Formula
# precision tp / (tp + fp)
InceptionNetV3_precision = precision_score(val_actual, val_predict, average="weighted")
print('InceptionNetV3 - Precision : %f' % InceptionNetV3_precision)

#Formula
# recall: tp / (tp + fn)
InceptionNetV3_recall = recall_score(val_actual, val_predict, average="weighted")
print('InceptionNetV3 - Recall : %f' % InceptionNetV3_recall)

#Formula
# f1: 2 tp / (2 tp + fp + fn)
InceptionNetV3_f1_sc = f1_score(val_actual, val_predict, average="weighted")
print('InceptionNetV3 - F1 score : %f' % InceptionNetV3_f1_sc)
# Out:
# InceptionNetV3 - Validation Accuracy: 0.908571
# InceptionNetV3 - Precision : 0.912929
# InceptionNetV3 - Recall : 0.908571
# InceptionNetV3 - F1 score : 0.908419

# %%
_, model_base_acc = model.evaluate(
   test_imgs, test_classes, verbose=0)

print('Test accuracy for base:', model_base_acc)
# Out:
# Test accuracy for base: 0.9085714221000671

# %% [markdown]
# ### Save the model

# %%
# model.save('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionnetV3/InceptionnetV3_New_Base_01.h5')

# %%
InceptionnetV3_model_base = load_model('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionnetV3/InceptionnetV3_New_Base_01.h5')

# %% [markdown]
# ### Calculate Inference time

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = InceptionnetV3_model_base.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
print("Inference time is: ", ir_time)
# Out:
# Predicted Class is: 1
# Inference time is:  0.05851452800015977

# %% [markdown]
# ## Model Pruning

# %%
# !pip install tensorflow_model_optimization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_model_optimization in /usr/local/lib/python3.7/dist-packages (0.7.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (0.1.7)
# Requirement already satisfied: six~=1.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (1.15.0)
# Requirement already satisfied: numpy~=1.14 in /usr/local/lib/python3.7/dist-packages (from tensorflow_model_optimization) (1.21.6)

# %%
import tensorflow_model_optimization as tfmot
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
# Compute end step to finish pruning after 2 epochs.
batch_size = 10
epochs = 2

end_step = np.ceil(train_imgs.shape[0]//batch_size).astype(np.int32) * epochs

# Define model for pruning.
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=end_step)
}

model_for_pruning = prune_low_magnitude(InceptionnetV3_model_base, **pruning_params)
# `prune_low_magnitude` requires a recompile.
model_for_pruning.compile(optimizer='adam',
              # loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              loss=['categorical_crossentropy'],
              metrics=['accuracy'])

model_for_pruning.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  prune_low_magnitude_conv2d (Pr  (None, 111, 111, 32  1730       ['input_1[0][0]']
#  uneLowMagnitude)               )
#
#  prune_low_magnitude_batch_norm  (None, 111, 111, 32  97         ['prune_low_magnitude_conv2d[0][0
#  alization (PruneLowMagnitude)  )                                ]']
#
#  prune_low_magnitude_activation  (None, 111, 111, 32  1          ['prune_low_magnitude_batch_norma
#   (PruneLowMagnitude)           )                                lization[0][0]']
#
#  prune_low_magnitude_conv2d_1 (  (None, 109, 109, 32  18434      ['prune_low_magnitude_activation[
#  PruneLowMagnitude)             )                                0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 109, 109, 32  97         ['prune_low_magnitude_conv2d_1[0]
#  alization_1 (PruneLowMagnitude  )                               [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 109, 109, 32  1          ['prune_low_magnitude_batch_norma
#  _1 (PruneLowMagnitude)         )                                lization_1[0][0]']
#
#  prune_low_magnitude_conv2d_2 (  (None, 109, 109, 64  36866      ['prune_low_magnitude_activation_
#  PruneLowMagnitude)             )                                1[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 109, 109, 64  193        ['prune_low_magnitude_conv2d_2[0]
#  alization_2 (PruneLowMagnitude  )                               [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 109, 109, 64  1          ['prune_low_magnitude_batch_norma
#  _2 (PruneLowMagnitude)         )                                lization_2[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 54, 54, 64)  1           ['prune_low_magnitude_activation_
#  g2d (PruneLowMagnitude)                                         2[0][0]']
#
#  prune_low_magnitude_conv2d_3 (  (None, 54, 54, 80)  10242       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 54, 54, 80)  241         ['prune_low_magnitude_conv2d_3[0]
#  alization_3 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 54, 54, 80)  1           ['prune_low_magnitude_batch_norma
#  _3 (PruneLowMagnitude)                                          lization_3[0][0]']
#
#  prune_low_magnitude_conv2d_4 (  (None, 52, 52, 192)  276482     ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              3[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 52, 52, 192)  577        ['prune_low_magnitude_conv2d_4[0]
#  alization_4 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 52, 52, 192)  1          ['prune_low_magnitude_batch_norma
#  _4 (PruneLowMagnitude)                                          lization_4[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 25, 25, 192)  1          ['prune_low_magnitude_activation_
#  g2d_1 (PruneLowMagnitude)                                       4[0][0]']
#
#  prune_low_magnitude_conv2d_8 (  (None, 25, 25, 64)  24578       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d_1[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_8[0]
#  alization_8 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _8 (PruneLowMagnitude)                                          lization_8[0][0]']
#
#  prune_low_magnitude_conv2d_6 (  (None, 25, 25, 48)  18434       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d_1[0][0]']
#
#  prune_low_magnitude_conv2d_9 (  (None, 25, 25, 96)  110594      ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              8[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_6[0]
#  alization_6 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_9[0]
#  alization_9 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _6 (PruneLowMagnitude)                                          lization_6[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _9 (PruneLowMagnitude)                                          lization_9[0][0]']
#
#  prune_low_magnitude_average_po  (None, 25, 25, 192)  1          ['prune_low_magnitude_max_pooling
#  oling2d (PruneLowMagnitude)                                     2d_1[0][0]']
#
#  prune_low_magnitude_conv2d_5 (  (None, 25, 25, 64)  24578       ['prune_low_magnitude_max_pooling
#  PruneLowMagnitude)                                              2d_1[0][0]']
#
#  prune_low_magnitude_conv2d_7 (  (None, 25, 25, 64)  153602      ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              6[0][0]']
#
#  prune_low_magnitude_conv2d_10   (None, 25, 25, 96)  165890      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             9[0][0]']
#
#  prune_low_magnitude_conv2d_11   (None, 25, 25, 32)  12290       ['prune_low_magnitude_average_poo
#  (PruneLowMagnitude)                                             ling2d[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_5[0]
#  alization_5 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_7[0]
#  alization_7 (PruneLowMagnitude                                  [0]']
#  )
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_10[0
#  alization_10 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 32)  97          ['prune_low_magnitude_conv2d_11[0
#  alization_11 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _5 (PruneLowMagnitude)                                          lization_5[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _7 (PruneLowMagnitude)                                          lization_7[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _10 (PruneLowMagnitude)                                         lization_10[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 32)  1           ['prune_low_magnitude_batch_norma
#  _11 (PruneLowMagnitude)                                         lization_11[0][0]']
#
#  prune_low_magnitude_mixed0 (Pr  (None, 25, 25, 256)  1          ['prune_low_magnitude_activation_
#  uneLowMagnitude)                                                5[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  7[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  10[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  11[0][0]']
#
#  prune_low_magnitude_conv2d_15   (None, 25, 25, 64)  32770       ['prune_low_magnitude_mixed0[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_15[0
#  alization_15 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _15 (PruneLowMagnitude)                                         lization_15[0][0]']
#
#  prune_low_magnitude_conv2d_13   (None, 25, 25, 48)  24578       ['prune_low_magnitude_mixed0[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_16   (None, 25, 25, 96)  110594      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             15[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_13[0
#  alization_13 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_16[0
#  alization_16 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _13 (PruneLowMagnitude)                                         lization_13[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _16 (PruneLowMagnitude)                                         lization_16[0][0]']
#
#  prune_low_magnitude_average_po  (None, 25, 25, 256)  1          ['prune_low_magnitude_mixed0[0][0
#  oling2d_1 (PruneLowMagnitude)                                   ]']
#
#  prune_low_magnitude_conv2d_12   (None, 25, 25, 64)  32770       ['prune_low_magnitude_mixed0[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_14   (None, 25, 25, 64)  153602      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             13[0][0]']
#
#  prune_low_magnitude_conv2d_17   (None, 25, 25, 96)  165890      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             16[0][0]']
#
#  prune_low_magnitude_conv2d_18   (None, 25, 25, 64)  32770       ['prune_low_magnitude_average_poo
#  (PruneLowMagnitude)                                             ling2d_1[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_12[0
#  alization_12 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_14[0
#  alization_14 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_17[0
#  alization_17 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_18[0
#  alization_18 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _12 (PruneLowMagnitude)                                         lization_12[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _14 (PruneLowMagnitude)                                         lization_14[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _17 (PruneLowMagnitude)                                         lization_17[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _18 (PruneLowMagnitude)                                         lization_18[0][0]']
#
#  prune_low_magnitude_mixed1 (Pr  (None, 25, 25, 288)  1          ['prune_low_magnitude_activation_
#  uneLowMagnitude)                                                12[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  14[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  17[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  18[0][0]']
#
#  prune_low_magnitude_conv2d_22   (None, 25, 25, 64)  36866       ['prune_low_magnitude_mixed1[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_22[0
#  alization_22 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _22 (PruneLowMagnitude)                                         lization_22[0][0]']
#
#  prune_low_magnitude_conv2d_20   (None, 25, 25, 48)  27650       ['prune_low_magnitude_mixed1[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_23   (None, 25, 25, 96)  110594      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             22[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 48)  145         ['prune_low_magnitude_conv2d_20[0
#  alization_20 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_23[0
#  alization_23 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 48)  1           ['prune_low_magnitude_batch_norma
#  _20 (PruneLowMagnitude)                                         lization_20[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _23 (PruneLowMagnitude)                                         lization_23[0][0]']
#
#  prune_low_magnitude_average_po  (None, 25, 25, 288)  1          ['prune_low_magnitude_mixed1[0][0
#  oling2d_2 (PruneLowMagnitude)                                   ]']
#
#  prune_low_magnitude_conv2d_19   (None, 25, 25, 64)  36866       ['prune_low_magnitude_mixed1[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_21   (None, 25, 25, 64)  153602      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             20[0][0]']
#
#  prune_low_magnitude_conv2d_24   (None, 25, 25, 96)  165890      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             23[0][0]']
#
#  prune_low_magnitude_conv2d_25   (None, 25, 25, 64)  36866       ['prune_low_magnitude_average_poo
#  (PruneLowMagnitude)                                             ling2d_2[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_19[0
#  alization_19 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_21[0
#  alization_21 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_24[0
#  alization_24 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_25[0
#  alization_25 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _19 (PruneLowMagnitude)                                         lization_19[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _21 (PruneLowMagnitude)                                         lization_21[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _24 (PruneLowMagnitude)                                         lization_24[0][0]']
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _25 (PruneLowMagnitude)                                         lization_25[0][0]']
#
#  prune_low_magnitude_mixed2 (Pr  (None, 25, 25, 288)  1          ['prune_low_magnitude_activation_
#  uneLowMagnitude)                                                19[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  21[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  24[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  25[0][0]']
#
#  prune_low_magnitude_conv2d_27   (None, 25, 25, 64)  36866       ['prune_low_magnitude_mixed2[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 64)  193         ['prune_low_magnitude_conv2d_27[0
#  alization_27 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 64)  1           ['prune_low_magnitude_batch_norma
#  _27 (PruneLowMagnitude)                                         lization_27[0][0]']
#
#  prune_low_magnitude_conv2d_28   (None, 25, 25, 96)  110594      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             27[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 25, 25, 96)  289         ['prune_low_magnitude_conv2d_28[0
#  alization_28 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 25, 25, 96)  1           ['prune_low_magnitude_batch_norma
#  _28 (PruneLowMagnitude)                                         lization_28[0][0]']
#
#  prune_low_magnitude_conv2d_26   (None, 12, 12, 384)  1990658    ['prune_low_magnitude_mixed2[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_29   (None, 12, 12, 96)  165890      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             28[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 384)  1153       ['prune_low_magnitude_conv2d_26[0
#  alization_26 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 96)  289         ['prune_low_magnitude_conv2d_29[0
#  alization_29 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 384)  1          ['prune_low_magnitude_batch_norma
#  _26 (PruneLowMagnitude)                                         lization_26[0][0]']
#
#  prune_low_magnitude_activation  (None, 12, 12, 96)  1           ['prune_low_magnitude_batch_norma
#  _29 (PruneLowMagnitude)                                         lization_29[0][0]']
#
#  prune_low_magnitude_max_poolin  (None, 12, 12, 288)  1          ['prune_low_magnitude_mixed2[0][0
#  g2d_2 (PruneLowMagnitude)                                       ]']
#
#  prune_low_magnitude_mixed3 (Pr  (None, 12, 12, 768)  1          ['prune_low_magnitude_activation_
#  uneLowMagnitude)                                                26[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  29[0][0]',
#                                                                   'prune_low_magnitude_max_pooling
#                                                                  2d_2[0][0]']
#
#  prune_low_magnitude_conv2d_34   (None, 12, 12, 128)  196610     ['prune_low_magnitude_mixed3[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 128)  385        ['prune_low_magnitude_conv2d_34[0
#  alization_34 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 128)  1          ['prune_low_magnitude_batch_norma
#  _34 (PruneLowMagnitude)                                         lization_34[0][0]']
#
#  prune_low_magnitude_conv2d_35   (None, 12, 12, 128)  229378     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             34[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 128)  385        ['prune_low_magnitude_conv2d_35[0
#  alization_35 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 128)  1          ['prune_low_magnitude_batch_norma
#  _35 (PruneLowMagnitude)                                         lization_35[0][0]']
#
#  prune_low_magnitude_conv2d_31   (None, 12, 12, 128)  196610     ['prune_low_magnitude_mixed3[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_36   (None, 12, 12, 128)  229378     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             35[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 128)  385        ['prune_low_magnitude_conv2d_31[0
#  alization_31 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 128)  385        ['prune_low_magnitude_conv2d_36[0
#  alization_36 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 128)  1          ['prune_low_magnitude_batch_norma
#  _31 (PruneLowMagnitude)                                         lization_31[0][0]']
#
#  prune_low_magnitude_activation  (None, 12, 12, 128)  1          ['prune_low_magnitude_batch_norma
#  _36 (PruneLowMagnitude)                                         lization_36[0][0]']
#
#  prune_low_magnitude_conv2d_32   (None, 12, 12, 128)  229378     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             31[0][0]']
#
#  prune_low_magnitude_conv2d_37   (None, 12, 12, 128)  229378     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             36[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 128)  385        ['prune_low_magnitude_conv2d_32[0
#  alization_32 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 128)  385        ['prune_low_magnitude_conv2d_37[0
#  alization_37 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 128)  1          ['prune_low_magnitude_batch_norma
#  _32 (PruneLowMagnitude)                                         lization_32[0][0]']
#
#  prune_low_magnitude_activation  (None, 12, 12, 128)  1          ['prune_low_magnitude_batch_norma
#  _37 (PruneLowMagnitude)                                         lization_37[0][0]']
#
#  prune_low_magnitude_average_po  (None, 12, 12, 768)  1          ['prune_low_magnitude_mixed3[0][0
#  oling2d_3 (PruneLowMagnitude)                                   ]']
#
#  prune_low_magnitude_conv2d_30   (None, 12, 12, 192)  294914     ['prune_low_magnitude_mixed3[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_33   (None, 12, 12, 192)  344066     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             32[0][0]']
#
#  prune_low_magnitude_conv2d_38   (None, 12, 12, 192)  344066     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             37[0][0]']
#
#  prune_low_magnitude_conv2d_39   (None, 12, 12, 192)  294914     ['prune_low_magnitude_average_poo
#  (PruneLowMagnitude)                                             ling2d_3[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 192)  577        ['prune_low_magnitude_conv2d_30[0
#  alization_30 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 192)  577        ['prune_low_magnitude_conv2d_33[0
#  alization_33 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 192)  577        ['prune_low_magnitude_conv2d_38[0
#  alization_38 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 192)  577        ['prune_low_magnitude_conv2d_39[0
#  alization_39 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 192)  1          ['prune_low_magnitude_batch_norma
#  _30 (PruneLowMagnitude)                                         lization_30[0][0]']
#
#  prune_low_magnitude_activation  (None, 12, 12, 192)  1          ['prune_low_magnitude_batch_norma
#  _33 (PruneLowMagnitude)                                         lization_33[0][0]']
#
#  prune_low_magnitude_activation  (None, 12, 12, 192)  1          ['prune_low_magnitude_batch_norma
#  _38 (PruneLowMagnitude)                                         lization_38[0][0]']
#
#  prune_low_magnitude_activation  (None, 12, 12, 192)  1          ['prune_low_magnitude_batch_norma
#  _39 (PruneLowMagnitude)                                         lization_39[0][0]']
#
#  prune_low_magnitude_mixed4 (Pr  (None, 12, 12, 768)  1          ['prune_low_magnitude_activation_
#  uneLowMagnitude)                                                30[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  33[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  38[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  39[0][0]']
#
#  prune_low_magnitude_conv2d_44   (None, 12, 12, 160)  245762     ['prune_low_magnitude_mixed4[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 160)  481        ['prune_low_magnitude_conv2d_44[0
#  alization_44 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 12, 12, 160)  1          ['prune_low_magnitude_batch_norma
#  _44 (PruneLowMagnitude)                                         lization_44[0][0]']
#
#  prune_low_magnitude_conv2d_45   (None, 12, 12, 160)  358402     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             44[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 12, 12, 160)  481        ['prune_low_magnitude_conv2d_45[0
#  alization_45 (PruneLowMagnitud                                  ][0]']
# ...
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _83 (PruneLowMagnitude)                                         lization_83[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 192)   577         ['prune_low_magnitude_conv2d_84[0
#  alization_84 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 5, 5, 320)   1           ['prune_low_magnitude_batch_norma
#  _76 (PruneLowMagnitude)                                         lization_76[0][0]']
#
#  prune_low_magnitude_mixed9_0 (  (None, 5, 5, 768)   1           ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              78[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  79[0][0]']
#
#  prune_low_magnitude_concatenat  (None, 5, 5, 768)   1           ['prune_low_magnitude_activation_
#  e (PruneLowMagnitude)                                           82[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  83[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _84 (PruneLowMagnitude)                                         lization_84[0][0]']
#
#  prune_low_magnitude_mixed9 (Pr  (None, 5, 5, 2048)  1           ['prune_low_magnitude_activation_
#  uneLowMagnitude)                                                76[0][0]',
#                                                                   'prune_low_magnitude_mixed9_0[0]
#                                                                  [0]',
#                                                                   'prune_low_magnitude_concatenate
#                                                                  [0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  84[0][0]']
#
#  prune_low_magnitude_conv2d_89   (None, 5, 5, 448)   1835010     ['prune_low_magnitude_mixed9[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 448)   1345        ['prune_low_magnitude_conv2d_89[0
#  alization_89 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 5, 5, 448)   1           ['prune_low_magnitude_batch_norma
#  _89 (PruneLowMagnitude)                                         lization_89[0][0]']
#
#  prune_low_magnitude_conv2d_86   (None, 5, 5, 384)   1572866     ['prune_low_magnitude_mixed9[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_conv2d_90   (None, 5, 5, 384)   3096578     ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             89[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 384)   1153        ['prune_low_magnitude_conv2d_86[0
#  alization_86 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 384)   1153        ['prune_low_magnitude_conv2d_90[0
#  alization_90 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _86 (PruneLowMagnitude)                                         lization_86[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _90 (PruneLowMagnitude)                                         lization_90[0][0]']
#
#  prune_low_magnitude_conv2d_87   (None, 5, 5, 384)   884738      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             86[0][0]']
#
#  prune_low_magnitude_conv2d_88   (None, 5, 5, 384)   884738      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             86[0][0]']
#
#  prune_low_magnitude_conv2d_91   (None, 5, 5, 384)   884738      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             90[0][0]']
#
#  prune_low_magnitude_conv2d_92   (None, 5, 5, 384)   884738      ['prune_low_magnitude_activation_
#  (PruneLowMagnitude)                                             90[0][0]']
#
#  prune_low_magnitude_average_po  (None, 5, 5, 2048)  1           ['prune_low_magnitude_mixed9[0][0
#  oling2d_8 (PruneLowMagnitude)                                   ]']
#
#  prune_low_magnitude_conv2d_85   (None, 5, 5, 320)   1310722     ['prune_low_magnitude_mixed9[0][0
#  (PruneLowMagnitude)                                             ]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 384)   1153        ['prune_low_magnitude_conv2d_87[0
#  alization_87 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 384)   1153        ['prune_low_magnitude_conv2d_88[0
#  alization_88 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 384)   1153        ['prune_low_magnitude_conv2d_91[0
#  alization_91 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 384)   1153        ['prune_low_magnitude_conv2d_92[0
#  alization_92 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_conv2d_93   (None, 5, 5, 192)   786434      ['prune_low_magnitude_average_poo
#  (PruneLowMagnitude)                                             ling2d_8[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 320)   961         ['prune_low_magnitude_conv2d_85[0
#  alization_85 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _87 (PruneLowMagnitude)                                         lization_87[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _88 (PruneLowMagnitude)                                         lization_88[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _91 (PruneLowMagnitude)                                         lization_91[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 384)   1           ['prune_low_magnitude_batch_norma
#  _92 (PruneLowMagnitude)                                         lization_92[0][0]']
#
#  prune_low_magnitude_batch_norm  (None, 5, 5, 192)   577         ['prune_low_magnitude_conv2d_93[0
#  alization_93 (PruneLowMagnitud                                  ][0]']
#  e)
#
#  prune_low_magnitude_activation  (None, 5, 5, 320)   1           ['prune_low_magnitude_batch_norma
#  _85 (PruneLowMagnitude)                                         lization_85[0][0]']
#
#  prune_low_magnitude_mixed9_1 (  (None, 5, 5, 768)   1           ['prune_low_magnitude_activation_
#  PruneLowMagnitude)                                              87[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  88[0][0]']
#
#  prune_low_magnitude_concatenat  (None, 5, 5, 768)   1           ['prune_low_magnitude_activation_
#  e_1 (PruneLowMagnitude)                                         91[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  92[0][0]']
#
#  prune_low_magnitude_activation  (None, 5, 5, 192)   1           ['prune_low_magnitude_batch_norma
#  _93 (PruneLowMagnitude)                                         lization_93[0][0]']
#
#  prune_low_magnitude_mixed10 (P  (None, 5, 5, 2048)  1           ['prune_low_magnitude_activation_
#  runeLowMagnitude)                                               85[0][0]',
#                                                                   'prune_low_magnitude_mixed9_1[0]
#                                                                  [0]',
#                                                                   'prune_low_magnitude_concatenate
#                                                                  _1[0][0]',
#                                                                   'prune_low_magnitude_activation_
#                                                                  93[0][0]']
#
#  prune_low_magnitude_global_ave  (None, 2048)        1           ['prune_low_magnitude_mixed10[0][
#  rage_pooling2d (PruneLowMagnit                                  0]']
#  ude)
#
#  prune_low_magnitude_dropout (P  (None, 2048)        1           ['prune_low_magnitude_global_aver
#  runeLowMagnitude)                                               age_pooling2d[0][0]']
#
#  prune_low_magnitude_dense (Pru  (None, 1024)        4195330     ['prune_low_magnitude_dropout[0][
#  neLowMagnitude)                                                 0]']
#
#  prune_low_magnitude_dense_1 (P  (None, 21)          43031       ['prune_low_magnitude_dense[0][0]
#  runeLowMagnitude)                                               ']
#
# ==================================================================================================
# Total params: 47,792,687
# Trainable params: 23,888,053
# Non-trainable params: 23,904,634
# __________________________________________________________________________________________________

# %%
logdir = tempfile.mkdtemp()

callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep(),
  tfmot.sparsity.keras.PruningSummaries(log_dir=logdir),
]
  
model_for_pruning.fit(train_imgs, train_classes,
                      steps_per_epoch=len(train_imgs)//10,
                      epochs=2,                     
                      verbose=1,
                      validation_data=(val_imgs,val_classes),
                      validation_steps=len(val_imgs)//10)
                      # callbacks=callbacks)
# Out:
# Epoch 1/2
# 735/735 [==============================] - 106s 142ms/step - loss: 0.1450 - accuracy: 0.9620 - val_loss: 0.8969 - val_accuracy: 0.7776
# Epoch 2/2
# 735/735 [==============================] - 101s 137ms/step - loss: 0.1018 - accuracy: 0.9721 - val_loss: 0.1891 - val_accuracy: 0.9529

# %%
model_for_pruning.save('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionnetV3/InceptionnetV3_after_pruning_05.h5')

# %%
# model_for_pruning = load_model('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/Pruned Model/InceptionnetV3/InceptionnetV3_after_pruning_05.h5')

# %%
val_pred_prun = model_for_pruning.predict(val_imgs)
val_pred_prun = np.argmax(val_pred_prun, axis=1)
val_pred_prun.shape
# Out:
# (2100,)

# %%
_, model_prun_acc = model_for_pruning.evaluate(
   test_imgs, test_classes, verbose=0)

# print('Test accuracy for base model:', model_base_acc) 
print('Test accuracy for Prunned model:', model_prun_acc)
# Out:
# Test accuracy for Prunned model: 0.9457142949104309

# %%
val_actual = np.argmax(val_classes, axis=1)

cnf_mat = confusion_matrix(val_actual, val_pred_prun)
np.set_printoptions(precision=2)

plt.figure()
show_conf_matrix(cnf_mat, classes=out_classes)
plt.grid(None)
plt.show();

# %% [markdown]
# ### Model Prediction Accuracy

# %%
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
#Formula
# accuracy: (tp + tn) / (p + n)
InceptionnetV3_Accuracy_prun = accuracy_score(val_actual, val_pred_prun)
print('Pruning InceptionnetV3 - Validation Accuracy: %f' % InceptionnetV3_Accuracy_prun)

#Formula
# precision tp / (tp + fp)
InceptionnetV3_precision_prun = precision_score(val_actual, val_pred_prun, average="weighted")
print('Pruning InceptionnetV3 - Precision : %f' % InceptionnetV3_precision_prun)

#Formula
# recall: tp / (tp + fn)
InceptionnetV3_recall_prun = recall_score(val_actual, val_pred_prun, average="weighted")
print('Pruning InceptionnetV3 - Recall : %f' % InceptionnetV3_recall_prun)

#Formula
# f1: 2 tp / (2 tp + fp + fn)
InceptionnetV3_f1_sc_prun = f1_score(val_actual, val_pred_prun, average="weighted")
print('Pruning InceptionnetV3 - F1 score : %f' % InceptionnetV3_f1_sc_prun)
# Out:
# Pruning InceptionnetV3 - Validation Accuracy: 0.952857
# Pruning InceptionnetV3 - Precision : 0.954532
# Pruning InceptionnetV3 - Recall : 0.952857
# Pruning InceptionnetV3 - F1 score : 0.952752

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = model_for_pruning.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
print("Inference time is: ", ir_time)
# Out:
# Predicted Class is: 9
# Inference time is:  0.06456178300140891

# %% [markdown]
# ### Grad-CAM Visual on Baseline Model

# %%
def grad_cam_heatmap(pred_img, model, lst_conv_layer, pred_index=None):
    #Created a model which maps the input image to activations of last conv layer and output predictions
    gradient_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(lst_conv_layer).output, model.output]
    )

    #Calculate gradient of top predicted class for input image for last conv layer activation
    with tf.GradientTape() as tape:
        lst_conv_layer_out, preds = gradient_model(pred_img)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channels = preds[:, pred_index]

    # Gradient of top predicted for output feature map of last conv layer
    grads = tape.gradient(class_channels, lst_conv_layer_out)

    # A vector of mean intensity of the gradient over feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # Multipled each channel in the feature map array to check importance of channel 
    # with respect to top predicted class and sum of all channel to get heatmap of class activation
    lst_conv_layer_out = lst_conv_layer_out[0]
    heatmap = lst_conv_layer_out @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    #Normalize a heatmap between 0 and 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def grad_cam_display(org_img_path, heatmap, grad_cam_path="grad_cam.jpg", alpha=0.4):
    # Load an image
    img = tf.keras.preprocessing.image.load_img(org_img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to 0-255 range
    heatmap = np.uint8(255 * heatmap)

    # color heatmap using jet colourmap
    jet = cm.get_cmap("jet")

    # Use RGB colormap values
    jet_colors = jet(np.arange(256))[:, :3]
    jet_color_heatmap = jet_colors[heatmap]

    # Created an image with RGB colored heatmap
    jet_color_heatmap = tf.keras.preprocessing.image.array_to_img(jet_color_heatmap)
    jet_color_heatmap = jet_color_heatmap.resize((img.shape[1], img.shape[0]))
    jet_color_heatmap = tf.keras.preprocessing.image.img_to_array(jet_color_heatmap)

    # Superimpose a heatmap on actual image
    superimposed_img = jet_color_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)

    superimposed_img.save(grad_cam_path)

    # Display Grad CAM
    # display(Image(grad_cam_path))
    
    return grad_cam_path
    
preprocess_input = tf.keras.applications.inception_v3.preprocess_input
decode_predictions = tf.keras.applications.inception_v3.decode_predictions

lst_conv_layer = "activation_93"
img_size = (224,224)

# Remove last layer's softmax
InceptionnetV3_model_base.layers[-1].activation = None

# %% [markdown]
# ###  Visualize image

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np
import time 
import matplotlib.cm as cm

# read and reshape the image
def prep_image(image):
    image = load_img(image, target_size=(224, 224))
    # Show image
    plt.imshow(image)
    plt.xticks([]), plt.yticks([])
    plt.show()
    # Read into an array
    image = img_to_array(image)
    image = image.reshape(1, 224, 224, 3)
    image = image.astype('float32')
    image = image / 255.0
    return image
 
# Read Image
pred_img = prep_image('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif')

# predict the class
start = time.perf_counter()
pre_class = InceptionnetV3_model_base.predict(pred_img)
pre_class=np.argmax(pre_class,axis=1)
end = time.perf_counter()

ir_time = end-start
print("Predicted Class is:", pre_class[0])
# print("Inference time is: ", ir_time)

img_path = '/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model'

# Calculate Grad-CAM class activation
gc_heatmap = grad_cam_heatmap(pred_img, InceptionnetV3_model_base, lst_conv_layer)
# print(heatmap)
g_cam_path = grad_cam_display('/content/gdrive/My Drive/Colab Notebooks/Final Model/Pruning Model/Formatted_Pruning_Model/airplane00_r.tif', gc_heatmap)
img = plt.imread(g_cam_path)
img = plt.imshow(img)

print("\n\nGrad-CAM Visual")
print("Predicted Class is:", pre_class[0])
# Out:
# Predicted Class is: 1
#
#
# Grad-CAM Visual
# Predicted Class is: 1
